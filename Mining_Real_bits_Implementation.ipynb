# %%
import hashlib  # For computing SHA-256 hashes
import time     # To timestamp blocks

# %% [markdown]
# In Bitcoin and many similar blockchains, the mining difficulty target is a 256-bit number. Storing this full 256-bit target in every block header would be inefficient, so a compact form called “bits” is used. This 32-bit (4-byte) field encodes the target using a floating‐point–like format:
#
# Exponent (1 byte):
# The most significant byte represents the exponent. It indicates how many bytes the full target takes up when expressed in big-endian format.
#
# Coefficient (3 bytes):
# The remaining three bytes represent the coefficient (or mantissa).
#
# The full target is then computed as:
#
#   target = coefficient × 2^(8 × (exponent – 3))
#
# When mining, a block’s hash is interpreted as a large integer. A block is considered valid if its hash is lower than this target value.

# %%
def bits_to_target(bits):
    """
    Convert the compact representation of the target (bits) to the full target value.
    
    The 'bits' value is a 32-bit unsigned integer:
      - The most significant byte is the exponent.
      - The remaining 3 bytes are the coefficient.
    
    The target is computed as:
         target = coefficient * 2^(8*(exponent - 3))
    """
    exponent = bits >> 24             # Extract the exponent (top 8 bits)
    coefficient = bits & 0xffffff     # Extract the coefficient (lower 24 bits)
    target = coefficient * (1 << (8 * (exponent - 3)))
    return target

# Example: Print target from a given bits value (commonly used in test networks)
bits_example = 0x1e0ffff0
target_example = bits_to_target(bits_example)
print("Example bits:", hex(bits_example))
print("Computed target:", hex(target_example))
# Out:
# Example bits: 0x1e0ffff0
# Computed target: 0xffff0000000000000000000000000000000000000000000000000000000

# %%
class Block:
    def __init__(self, index, previous_hash, data):
        self.index = index                        # Position of the block in the chain
        self.timestamp = time.time()              # Time when block is created
        self.data = data                          # Block data (e.g., transactions)
        self.previous_hash = previous_hash        # Hash of the previous block in the chain
        self.nonce = 0                            # Value to be adjusted during mining
        self.hash = self.compute_hash()           # Initial hash based on current values

    def compute_hash(self):
        # Concatenate block attributes into a string and compute its SHA-256 hash.
        block_content = f"{self.index}{self.timestamp}{self.data}{self.previous_hash}{self.nonce}"
        return hashlib.sha256(block_content.encode()).hexdigest()

# %%
def mine_block(block, bits=0x1e0ffff0, verbose=True):
    """
    Mines a block by finding a nonce such that the block's hash (interpreted as an integer)
    is lower than the target computed from the 'bits' value.
    
    Parameters:
      - block: The Block object to be mined.
      - bits: The compact representation of the target (default provided is 0x1e0ffff0).
      - verbose: If True, prints detailed debug info during mining.
      
    Returns:
      The valid nonce and hash when the block is successfully mined.
    """
    target = bits_to_target(bits)
    if verbose:
        print(f"\nStarting mining for Block {block.index} with target: {hex(target)}")
    iteration = 0
    # Loop until the block's hash, converted to an integer, is lower than the target.
    while int(block.hash, 16) >= target:
        block.nonce += 1
        block.hash = block.compute_hash()
        iteration += 1
        # For demonstration, print every 1000 iterations to avoid excessive output.
        if verbose and iteration % 1000 == 0:
            print(f"Iteration {iteration}: nonce = {block.nonce}, hash = {block.hash}")
    if verbose:
        print(f"Block {block.index} mined after {iteration} iterations!")
        print(f"Final nonce: {block.nonce}, Final hash: {block.hash}\n")
    return block.nonce, block.hash

# %%
class Blockchain:
    def __init__(self):
        self.chain = []             # List to store blocks in the blockchain
        self.bits = 0x1e0ffff0      # The compact "bits" representation for mining target
        self.create_genesis_block()

    def create_genesis_block(self):
        # Create the first block with default previous hash "0"
        genesis_block = Block(0, "0", "Genesis Block")
        mine_block(genesis_block, self.bits, verbose=True)
        self.chain.append(genesis_block)

    def add_block(self, data):
        # Create a new block using the hash of the latest block as its previous_hash
        last_block = self.chain[-1]
        new_block = Block(len(self.chain), last_block.hash, data)
        mine_block(new_block, self.bits, verbose=True)
        self.chain.append(new_block)

    def display_chain(self):
        # Print detailed information for each block in the blockchain.
        for block in self.chain:
            print(f"Index: {block.index}")
            print(f"Timestamp: {block.timestamp}")
            print(f"Data: {block.data}")
            print(f"Previous Hash: {block.previous_hash}")
            print(f"Nonce: {block.nonce}")
            print(f"Hash: {block.hash}")
            print("-" * 50)

# %%
# Initialize the blockchain (genesis block is created and mined automatically)
blockchain = Blockchain()

# Display details of the genesis block
print("Genesis Block:")
genesis = blockchain.chain[0]
print(f"Index: {genesis.index}")
print(f"Timestamp: {genesis.timestamp}")
print(f"Data: {genesis.data}")
print(f"Previous Hash: {genesis.previous_hash}")
print(f"Nonce: {genesis.nonce}")
print(f"Hash: {genesis.hash}")
print("-" * 50)
# Out:
# Starting mining for Block 0 with target: 0xffff0000000000000000000000000000000000000000000000000000000
# Iteration 1000: nonce = 1000, hash = 938bcc67245030a1600323580a78f7b841499713aa100134e981626e83b9a420
# Iteration 2000: nonce = 2000, hash = 0c9c1f6210e288872e24021de0433db083a4e738bb018461e403dd31314f9e9c
# Iteration 3000: nonce = 3000, hash = decaf4c1aac06bc0567ce029d0b744dcc65444b4c85d235818b33e88d41ee163
# Iteration 4000: nonce = 4000, hash = 89ab825721b8b90d6b25e4b6ec5efd5ae875e22f0e635f1535bcf64fab46b758
# Iteration 5000: nonce = 5000, hash = 3a03b88017b3291bc18ab01eb1d2d24489b4ea0c8df2d2ac8928120def02ab4b
# Iteration 6000: nonce = 6000, hash = 63c6a28cddf9cf6f88ce52fbfaa3877cf2551370109c25e1440d19d5e0f37ec5
# Iteration 7000: nonce = 7000, hash = 2f8f6a7b511de6d89bbce52bcdedde8a791ee7798aa807e3d7da1ac9213799a3
# Iteration 8000: nonce = 8000, hash = f4a8ef1dacae943b3fb8e0b53b9f3d9b4a8965411cd28a98ec6439884c0aec24
# Iteration 9000: nonce = 9000, hash = fe85b52a6a276d5cd17f484666aed8f503d75b29c66d195912c4ca17ef933815
# Iteration 10000: nonce = 10000, hash = 4cf21470e211dba3f36acc9601011115730815ee8e02a9bec12fbdb209f1f754
# Iteration 11000: nonce = 11000, hash = 16cdcbf225d08a04be2d7cfa4f43049a763a14dcb6a131380bd026df5a1b6707
# Iteration 12000: nonce = 12000, hash = 9a70e0d3487a324e834e8ee7122e5f1282ee32d07169055fa97424c203631131
# Iteration 13000: nonce = 13000, hash = 7b223518bb0e86e32652eaa6fea0e34284fb57106be70d2c1fa51a330480c776
# Iteration 14000: nonce = 14000, hash = 239a6f4031593964a0ea892baaead5c3f1ed9fc8cdac1c64c2b8794d1f6de062
# Iteration 15000: nonce = 15000, hash = 9438725cc9b6e068535257ea23f3bcd17df5ec732a51a8c0b72dd97a2ebc98a9
# Iteration 16000: nonce = 16000, hash = 24b68dbc6c64af170a2d74ed0ed01f42dc0132f31361ea19da766e77cf10bd08
# Iteration 17000: nonce = 17000, hash = 3058085c05abbfe23823be2d8db5b1954d3a0e9485917cde4d380fecdca9c210
# Iteration 18000: nonce = 18000, hash = 69f2b8b41f062fce9ce713edddf2bde76f24446dfdd85529ac6eabfb424cd085
# Iteration 19000: nonce = 19000, hash = 0bfb2521249275b51f685f85594c2d38ee6747d8e8bdef3a7b55c47c2cd31356
# Iteration 20000: nonce = 20000, hash = 39c351b76ca9afe158acba24454875df0be9afbd3f2e59713654f400a24b7be2
# Iteration 21000: nonce = 21000, hash = 61f20964b08527ca2efbaa44191ddafc56376805a3ed2bbaab91ffca526b06c8
# Iteration 22000: nonce = 22000, hash = 254561775e67952c5339b34aa522083182610c1fb4c8b905fe5b93e5fa8d3b51
# Iteration 23000: nonce = 23000, hash = ec0bfac58db4a0766ac05785c6d38780a722190a894626ec65c122624b0819bc
# Iteration 24000: nonce = 24000, hash = af323b5ca574baa445595d759ef0daf9cd1e74ed147d3dc163d5ecdfb7c6c932
# Iteration 25000: nonce = 25000, hash = a4eb598d5c8c58793c33cdcd893a5712794b054ab301a7b9a325d5dd1eefadcc
# Iteration 26000: nonce = 26000, hash = 2ba2d47c1f47dc4aa183ef1c2e343b0d8960da66ae34856de559663e517bd944
# Iteration 27000: nonce = 27000, hash = bd476c0adc07f9f4c21f323a9235cb772b223432cc85f505c5b5d6a46a71f212
# Iteration 28000: nonce = 28000, hash = 5d5e5b28a3f89c40ffb325d3df51cb8e85a2d1997d2cca49945450fd5ef14259
# Iteration 29000: nonce = 29000, hash = 9d5148840bb9a392b57782a9eba1167276d05ad8b895514f9e34e549fd503247
# Iteration 30000: nonce = 30000, hash = aca950b12f9865b48abd8a3a4818f2b958e7bda72b081a09c24cf277021db84e
# Iteration 31000: nonce = 31000, hash = 2d57ea4846b575b0f5ddf538a0abeb3aece957a3aeccad3146e342aa52d42842
# Iteration 32000: nonce = 32000, hash = 3942c3f1cf3caa709032d058ae9e8daaa0816d1af6024d06243a47eec63527b7
# Iteration 33000: nonce = 33000, hash = fd59cbab839998252eeeec41a209b387faa2b4135e17b1817c661626c88352b2
# Iteration 34000: nonce = 34000, hash = 5023588d3a80d34bac7839ca5b6983e972258572f63af97c875795de9e7a8886
# Iteration 35000: nonce = 35000, hash = d42a2100b631120002a86b0dff1d1fa70b895b83645fc5430696c4500dfca062
# Iteration 36000: nonce = 36000, hash = f464c13d4a80f8f9b48202323524dc4070760e26d12a31dfbebfbf6f1031e3f9
# Iteration 37000: nonce = 37000, hash = 93694dc7adbf1a1ddd73e8e25ef6033678b16636f1de0aaa68cea679bb362094
# Iteration 38000: nonce = 38000, hash = e56d90f9516dbb8e4fd5907593e41bf4df970eec3065b204b5f13bb5fde1f31e
# Iteration 39000: nonce = 39000, hash = 2d2f034894cb65fd14cf16071389f40bdf02625381f692797ff3bba3c263584e
# Iteration 40000: nonce = 40000, hash = 402c8fbf62069005ecc3431173786daf0c6a295edde12a7fdb0e40a8b9d41a1a
# Iteration 41000: nonce = 41000, hash = ad3644bcc013cdd3203546b836a7357741e3ed4f07fa9475bb9be7d057c24496
# Iteration 42000: nonce = 42000, hash = 2b023697e26e0969231126f25fb817c784476beb1fbcb7ea3363c40a5a48bee5
# Iteration 43000: nonce = 43000, hash = af407469d5728e85df9b3f66d73cb10fe61f144cf3cf241adc2dd377a046af18
# Iteration 44000: nonce = 44000, hash = 8789af80f50e2433f15e1ecb5d7deca147cdd4fbfd4d0ef8ce61545c0a6ff3bb
# Iteration 45000: nonce = 45000, hash = ce7738997cf9d0d87d63d4bde1911171f0bc67bce24ca90f807dcdbdb09bc9a8
# Iteration 46000: nonce = 46000, hash = bbdff09adfdbb6883a364463f12a9560d808c9ff9c34798deeb8092f4f5b6e83
# Iteration 47000: nonce = 47000, hash = 73c037e0c8785dc15e79f882a2f6e2a22732b40e155a3736dd76c27b87f01178
# Iteration 48000: nonce = 48000, hash = 02874f8cc22edd2f7aea0f7d2c5f93d2206f836219f8938a1c1acaaee0b32cdc
# Iteration 49000: nonce = 49000, hash = 4885512e3e6abbdc7cadca7ae5f7584514fa42c436afa0c2af094c8316305b4b
# Iteration 50000: nonce = 50000, hash = 9c193782ff6935678ee2ffa94eb6f8124fd997a380d6bd2e85ca94e24a22619d
# Iteration 51000: nonce = 51000, hash = c212657567359515dbf1476732deea3417daa602baeefa6fda552488f91dcc8c
# Iteration 52000: nonce = 52000, hash = 402036d26431c9a5e2fedc84f134587ea7260592d0ea6104984450d939883482
# Iteration 53000: nonce = 53000, hash = e7c08bc8912ce1d1e00113301a1bbbb206dc0aa34d7bb5749b19c0f5ccfdd27e
# Iteration 54000: nonce = 54000, hash = 3fffee70f96d46431a64f4ab31ac6b604d70deeaf492555affc34eda86887019
# Iteration 55000: nonce = 55000, hash = 1a03aeb1276a8bee42ca3d3d16f048b063e36a1dd8f657fbde294101a32820cb
# Iteration 56000: nonce = 56000, hash = ac7d6c77d31ea8033e3eceb66b48bfbccdb997dca41a29b3f2aaeb1e95cd7112
# Iteration 57000: nonce = 57000, hash = a40257ef0bbafeb7419fe9da65900a42b9841914c418bc5324530d232d5b07ff
# Iteration 58000: nonce = 58000, hash = efbeeec2e489003a6ca04beb88c3e22b48cf702cab21e340475427cdf927a95d
# Iteration 59000: nonce = 59000, hash = e783939a58c61161de7ec0f4a739d91558d04ac8b3dc0ccafc4c79a4eab5be02
# Iteration 60000: nonce = 60000, hash = 3b4d7e362db1b0864159240817585c8256db5e79789deca39c9fdefb31ea8227
# Iteration 61000: nonce = 61000, hash = 3f78f68c8c628318c4649f9c2bf5df1bcd723aa69943a51b3bf38e982a5a4ca8
# Iteration 62000: nonce = 62000, hash = 13566524471d05085c5bb54b76bfc67bc0c78bf793510d5684107a6554bb77d8
# Iteration 63000: nonce = 63000, hash = b6fc3f3d691213ca58ce69ba0e69c1ab713d2f4779955be93b8f67a1706c9a16
# Iteration 64000: nonce = 64000, hash = 48cea6ca9a3574bae18c201019e775555a42260460124ef3b63bc142b0332028
# Iteration 65000: nonce = 65000, hash = 420010c29de447dd846b7d069de696296d72a6810c558b98d0e13c488dcdb9cf
# Iteration 66000: nonce = 66000, hash = 7526164a74f2dceb63b9a8eebbd90e47dd2d2d44acadd8b596885a2f64f91fd3
# Iteration 67000: nonce = 67000, hash = 8bc18fd411e772662edacc4ae8f6c764d63b110814e95a70293c10e6067c82f7
# Iteration 68000: nonce = 68000, hash = f9e3d3b3f441c8f840a032a10ea496b04ea810ea16229727982e20e41b70329a
# Iteration 69000: nonce = 69000, hash = efb94992be9ce678a4d50f443b7cb0ece1bd7734003e1f807f5dcd49a5925dc8
# Iteration 70000: nonce = 70000, hash = 34687bbc9030955dd2e8b4217ec0ec842888bdf459105971414d9a61692d207b
# Iteration 71000: nonce = 71000, hash = e429863ec283da957108413aab4b2378e330d06c87020ec1a93b9d204571b3c8
# Iteration 72000: nonce = 72000, hash = 0250f5327ec086ff494e8edc540b165102601c6771bf07ac36092b02910eff25
# Iteration 73000: nonce = 73000, hash = fb99cc53636e0da3881e32d996bf34b1de0390b60bf1b3449ccd281a0c54c31f
# Iteration 74000: nonce = 74000, hash = 5a88d798cd70e5a8e27aa3d5c1bec764a71cd2829ef2bc0f4c6e92e0c0313a07
# Iteration 75000: nonce = 75000, hash = 8f121286f0cc674cfe78769308e751ee9bcb49ee34132aa14411e07dc908d240
# Iteration 76000: nonce = 76000, hash = 0d42b6f18e149fa90c15c5da8abeff64e3a5627b9801623fdb4e3045191e73c6
# Iteration 77000: nonce = 77000, hash = 6d07b225c797bc5bfa949a6ef3f1e57299dc743a037708a14e756e270e647d55
# Iteration 78000: nonce = 78000, hash = 9b08416c668b307d2df061c7d08565ace85d669c351f84311bf3a8dbd2eab468
# Iteration 79000: nonce = 79000, hash = 7369ab092e87e1f8ff8f23c5cd5db30b9c060cf2d1a30d8197e29c5d4da30a88
# Iteration 80000: nonce = 80000, hash = 37683bcb6ec469c73ec6a0ea1006c486261c1e959c796d171d8e5820e2e3b066
# Iteration 81000: nonce = 81000, hash = 55225775bce7df41cddf66b3c345e83044ba879c11acb6b5dbbb6873638d7c31
# Iteration 82000: nonce = 82000, hash = 7805b74ab3ae4537e4e54aec8fb67b6d9b639e91f0cee6cd3ee1b47ae033a21e
# Iteration 83000: nonce = 83000, hash = 76b35370fc8e8dced44e45a1f5048e625db731d726ffc72893457d5ba8c539bb
# Iteration 84000: nonce = 84000, hash = 74b23c80034e3d09ad5466628e4450662c1cb120d852685ec19f621195d2a1ac
# Iteration 85000: nonce = 85000, hash = a721737f3f73985e50666e743502d1042b35d9ad1a2e0e49a60412e0a2e77233
# Iteration 86000: nonce = 86000, hash = 423b670a8202a83975212fc421990bf4591c6e90de7a1500153ad777578e3d05
# Iteration 87000: nonce = 87000, hash = 6856c6faf673009dfa261011e0300587463e3475805a3f80f108c157e8c62140
# Iteration 111000: nonce = 111000, hash = 719183dbf48d4e9719c281f9951f031a1c3c8d113e142ea80e9d1ccceddcbd35
# Iteration 112000: nonce = 112000, hash = 0504caa98501a0382ad0ec9091b0c1db295f51b42cdb5a4c347afc68ca3009b0
# Iteration 113000: nonce = 113000, hash = 49ad92d74ea87bf27a5b66ee4bbfceb4eb3dffeb17dd19576a640913d028d386
# Iteration 114000: nonce = 114000, hash = 14b581a4c06d4908dbae183b9d1eacf028da27827f12d08fc982c18bc791adc5
# Iteration 115000: nonce = 115000, hash = 65b86270170771f69ec230dc008f5563b7202963fd1365d196ef60b776f0208b
# Iteration 116000: nonce = 116000, hash = 5aa99ef9fbf7a6878a383714b19ed8fb7fc6860e47403669c7920336f95b353d
# Iteration 117000: nonce = 117000, hash = e762c6015503fc7bf2ee0fae47b9b85960e6777cf934754764fb9a8cdbef86a9
# Iteration 118000: nonce = 118000, hash = b11d109231ef1a1e15067ce057061b7e0d7260c24b06e2ca57da0de0b927824c
# Iteration 119000: nonce = 119000, hash = d71c171a483ca2f080ced6d8f7c3e658264639c60f1a267aaf3454204f4cceb2
# Iteration 120000: nonce = 120000, hash = 341f9c28042c76356790b44d2a342e00ec3f9c1b28aeebc978ef2545202b5442
# Iteration 121000: nonce = 121000, hash = 9a428c5756e8014b2c35f245a29cc09d473083880dff854f7f93baa942b74ee1
# Iteration 122000: nonce = 122000, hash = 147746d2adaa766570bc337dfae098188a9905a888be1f03b80705d4ed6c01e2
# Iteration 123000: nonce = 123000, hash = 81e3bc26e718ed05763e02477084033f4a4137adc8afcf8d9c7561d329bc5ef6
# Iteration 124000: nonce = 124000, hash = 68f3bcac722ab728d251112f207d71f1ca1b03ade6ad5572259f4d7801d93905
# Iteration 125000: nonce = 125000, hash = d5f622030dc3c28e00ba960c5b180eb800a9ea05db8695dbf0cbb6ddb343eb90
# Iteration 126000: nonce = 126000, hash = 09192db2d76ef58821914bb828eb2f06b7b668fa289ee0611f3c76f79a1b56dd
# Iteration 127000: nonce = 127000, hash = c1d7c3e1eeef083ea0b36c1adf5b3879bf7c40446b1529ddc274bd5c8b238bd1
# Iteration 128000: nonce = 128000, hash = 96ccbea5b83574a2dc5e100d0173e0f92e879ae70748dbab5ecaf2cc201c870c
# Iteration 129000: nonce = 129000, hash = d392d63f88db76561d87f59f199a342796a951243384156a5989914920922249
# Iteration 130000: nonce = 130000, hash = 51059c78d4158447d151ea8d6f9de87077e50b3335702f15bcc5fb229ebc8dfb
# Iteration 131000: nonce = 131000, hash = 557911337b7022f2aa8f58ac445252e2f4432232c3bd38e1e7db23303da62cf1
# Iteration 132000: nonce = 132000, hash = 9ae450184e51084d1df2d754aa9dfa039181f31e86a971c09f8dba0154cf00f3
# Iteration 133000: nonce = 133000, hash = c178f70e8b413ce7da6e4c379afaf79d4491dd249190c5dd4b8bd8c5dbe6576d
# Iteration 134000: nonce = 134000, hash = 3a8f6ddf8349c0cce8ddde7d539f14b8e7630360b045c383a32f0a01fa26ff0c
# Iteration 208000: nonce = 208000, hash = d03b58cb47e854adf0c81ff17b7d890cc6bdd3650d17443f146a388c4fc438ac
# Iteration 209000: nonce = 209000, hash = 4c62d5e47869e99dc541083dacfe0a4580284ffe1fc941a36f6c0e6a75cab548
# Iteration 210000: nonce = 210000, hash = 172772731fd3a1cb7dec64eed4c5ba0811b0db6fd8487628f09407bfdfb0ad46
# Iteration 211000: nonce = 211000, hash = 40e88d9c417bc4646867030f933ed02acb5db032702e8c3d3f1a41239777ad35
# Iteration 212000: nonce = 212000, hash = e5fb8b94eb25135d46d75ace19b41b75eacc11dc37ee6f390d942d8ae3584f44
# Iteration 213000: nonce = 213000, hash = 4d064a1f3b6aac1afdbe0b42c2ab60d7c706465344f778b9f07e6c20b3add459
# Iteration 214000: nonce = 214000, hash = 0d29de97c9f9a06d0e4b20e8fa885cd4f2331406e3bf1c3a0ccc08bda59fd287
# Iteration 215000: nonce = 215000, hash = 4acf5e68c81f6c36615bb48764f819e1f4c6c256e344a6d68143010881891d7a
# Iteration 216000: nonce = 216000, hash = 9e94fc24547ee98e514fb206e89474406558ac527207f26d022bfde181008b8e
# Iteration 217000: nonce = 217000, hash = 2d8be565ebfd580c4906dfc0b9f15f777c3cb397a566f124fc91d08b380b44ba
# Iteration 218000: nonce = 218000, hash = c1db79cb32b33a96da5ce6dbded224be23672abd1d3d277e43b1e710257b5fe5
# Iteration 219000: nonce = 219000, hash = 6074b1f8dff3a1fdf292448a529f0fd37c0bb6bce08b3e1ee89a21eb64173f64
# Iteration 220000: nonce = 220000, hash = 9c6b25207bfe8b1aa1c6a4866f3027f170313ff0d8829048c36810ccca46588c
# Iteration 221000: nonce = 221000, hash = 8ee93efff0510e86d2c2fe20f16ae7eeca0d691fd5f2269be9b1995ec3f3fe7e
# Iteration 222000: nonce = 222000, hash = e9ad016daf9c244fbe4169ee94261ce71bfcccdf77f6faa29b2b305bad57ab3c
# Iteration 223000: nonce = 223000, hash = 3ab5a7012d78ccc4a4479bdacaa0575c7b8a0c9beb6981ecad321790861e6929
# Iteration 224000: nonce = 224000, hash = a0cda6b997f9304b1575f2135f0d960c5258e12b13898db7ddfd077f6e39cfd7
# Iteration 225000: nonce = 225000, hash = cff7a6c5825eec15cd543fc5cd910e6c3d89b3df5b4ba18b813d5fc9a9098bf7
# Iteration 226000: nonce = 226000, hash = 50feb75119b75bb34634f59349d38bf8d6030ba145e1816ca4343ae9eda52930
# Iteration 227000: nonce = 227000, hash = 172f2434e047764f81a383b06af49d41f9d0429b07cce4ade8508eb67e7526bb
# Iteration 228000: nonce = 228000, hash = 5b0045eda34dc1aeccd5ebfce9dd3e75d8a943611a5ac669d58d0166196f011b
# Iteration 229000: nonce = 229000, hash = 98da056c48351d8be14301182b4703b334668ede836011f9998fc774984716ae
# Iteration 230000: nonce = 230000, hash = 73ec1cff7340888086f2d2e5c5d14f1bbe81919c85a4209dae7aff887545c9e0
# Iteration 231000: nonce = 231000, hash = 1612ab6046a250fa15f80bfb581501562b7c4b6c0580eab65737d5f067c423b1
# Iteration 232000: nonce = 232000, hash = 30a0bfbdf812d877422a258f4a543b134569497d39eacfd721cd02ba10b2f7b7
# Iteration 233000: nonce = 233000, hash = 5814508c05d219b2b179cb5f4762f1af5f03c55495d8f1d390c1e16ea7768925
# Iteration 234000: nonce = 234000, hash = ea353288045f9a098d3b98c10d7a5e194e9c57d684d4f7f59fa1c33a5e9ab5ea
# Iteration 235000: nonce = 235000, hash = d5f836cd15428a0d21ef9922d03e88315a21bf0384032dce5e4843e2a0a5f269
# Iteration 236000: nonce = 236000, hash = 3dff2eda6776eb27c5edb64a6ebce24352e50dbf798328658cd560a53e886ea9
# Iteration 237000: nonce = 237000, hash = c2055e217ea90723457c0c2b114a8eab1233c0a3b92396aec06a42bb7e8239f2
# Iteration 238000: nonce = 238000, hash = 4229085ee17f3037eb8d9958aefed9b78c3d4a4fbfb0b20635e476ff1ce9f887
# Iteration 239000: nonce = 239000, hash = da9f31f018929d7ae1bf14fe02ec958398a03ec5a6929298d7cbcd39145d35b4
# Iteration 240000: nonce = 240000, hash = aae3b66ad949d980cb6d62bee5dbf484e456cd67296e3b08397bf74b74892057
# Iteration 241000: nonce = 241000, hash = acd31563e80fad5cc933c481520c272df61dba976a640ed90c864615c94a75e1
# Iteration 242000: nonce = 242000, hash = 888beef1f262c40835b78857161124896969dae2d652ff7885a8904ee8c8a15b
# Iteration 243000: nonce = 243000, hash = 10a1cb7e0504d6c701c97276b6c922b4d0908ef40406adf66fff3e11680aba41
# Iteration 244000: nonce = 244000, hash = 4b31d6e269cf51517f89f9b9d721ad045db10071327911608cb2e82e10ad25fe
# Iteration 245000: nonce = 245000, hash = 0bf7b3acdcac89bea3327ab644c3acdf5d5c7fa99296a83c59d2c3a8c53cee9a
# Block 0 mined after 245022 iterations!
# Final nonce: 245022, Final hash: 000007b53e47c6f6fea7e8c1b1cc932a9d58f827cfbb1fcc2753aaedbf15118d
#
# Genesis Block:
# Index: 0
# Timestamp: 1742829912.5727808
# Data: Genesis Block
# Previous Hash: 0
# Nonce: 245022
# Hash: 000007b53e47c6f6fea7e8c1b1cc932a9d58f827cfbb1fcc2753aaedbf15118d
# --------------------------------------------------

# %%
# Add the first block with sample transaction data.
blockchain.add_block("Transaction A to B: $50")
print("Added Block 1:")

# Display details of the newly added block.
block1 = blockchain.chain[-1]
print(f"Index: {block1.index}")
print(f"Timestamp: {block1.timestamp}")
print(f"Data: {block1.data}")
print(f"Previous Hash: {block1.previous_hash}")
print(f"Nonce: {block1.nonce}")
print(f"Hash: {block1.hash}")
print("-" * 50)

# Add the second block.
blockchain.add_block("Transaction C to D: $20")
print("Added Block 2:")
block2 = blockchain.chain[-1]
print(f"Index: {block2.index}")
print(f"Timestamp: {block2.timestamp}")
print(f"Data: {block2.data}")
print(f"Previous Hash: {block2.previous_hash}")
print(f"Nonce: {block2.nonce}")
print(f"Hash: {block2.hash}")
print("-" * 50)

# Add the third block.
blockchain.add_block("Transaction E to F: $100")
print("Added Block 3:")
block3 = blockchain.chain[-1]
print(f"Index: {block3.index}")
print(f"Timestamp: {block3.timestamp}")
print(f"Data: {block3.data}")
print(f"Previous Hash: {block3.previous_hash}")
print(f"Nonce: {block3.nonce}")
print(f"Hash: {block3.hash}")
print("-" * 50)
# Out:
# Starting mining for Block 1 with target: 0xffff0000000000000000000000000000000000000000000000000000000
# Iteration 1000: nonce = 1000, hash = f3afa4e41851b04a2047ed19dc13ab9d7e0a50e9dc594b721113b8cfe1a96404
# Iteration 2000: nonce = 2000, hash = f0206b72b7755a8a06dd020f960cdce686cb2841a4e4436ad30ad39d38c19ccf
# Iteration 3000: nonce = 3000, hash = 55378587c6417f41742ca29a60552a927b801157d9fc31257bda651a6d44c680
# Iteration 4000: nonce = 4000, hash = 450a183f21f6eb7373cddc1dcfaf52762436cc69fcd94d109b6fda0abba120e6
# Iteration 5000: nonce = 5000, hash = 048266b23e6e16bcf51bc00e313cc69f6f1ba37b7d36c2aea20e7bf563005b77
# Iteration 6000: nonce = 6000, hash = 364ce84426ab73968cdee3a96342a81db9b7c6f543752e9c56604d78317600b7
# Iteration 7000: nonce = 7000, hash = b9f213e56e9003f5d98581e1f596ffcf86a74287bf28d86f831bf460e9823fe5
# Iteration 8000: nonce = 8000, hash = c5d0a14d49a7261c36fd2defc39b3f81866fc74ee78ae801c35b9c53a6b4cad8
# Iteration 9000: nonce = 9000, hash = 21c966e780142986e3c5cd85f177fc3d337baf681e23387e772e291ba1cf7ba7
# Iteration 10000: nonce = 10000, hash = 07471f71dc8e6d5732dd9b404de1f69412f039959ce6e4e0a125b460f90a2f67
# Iteration 11000: nonce = 11000, hash = 4b5bb9df6d8ff95b5f85cc3c8ed07ba3571d03c2e491db74876cad7073200727
# Iteration 12000: nonce = 12000, hash = 9805d76c0ead4778506b65a27387406b29212c8bc6307c49460a07967ef4b298
# Iteration 13000: nonce = 13000, hash = 5b37417d09f3cafc6b5788a827a766decd32476ed18c13192a28da2de6d0aaf3
# Iteration 14000: nonce = 14000, hash = 11b1bb6001aeba4edec6f64169b5c810d97c685cf576dc3e0416ae180d810b62
# Iteration 15000: nonce = 15000, hash = a81f960d16be6e754fd7ecc5f64cc42c7b5dd771c6396c8743055ad971a03856
# Iteration 16000: nonce = 16000, hash = 9d0029959819555d34a5b1149e4cda250a0f6a37887fee9ad8bec62b684bc42d
# Iteration 17000: nonce = 17000, hash = ccbd6951ea91d6e2e80b048df92a1a3731ddd14226ee8592c418ea88bcf9e4f3
# Iteration 18000: nonce = 18000, hash = 75b0f5df2615bb19ed029764506a91b1b848cd19641752dbe4b88bf573ec8e0c
# Iteration 19000: nonce = 19000, hash = 23926b3f9e4b05cbb5816d52522dfb74d2fab091c4ef1c6961465dca9230dc8b
# Iteration 20000: nonce = 20000, hash = 3ad2edd675a8a1304d0ff299ac8a30699e87a15315127bf91f27ebb11b1d77d9
# Iteration 21000: nonce = 21000, hash = c719206e876f27ee8d04a5a418fff3d073a22010f19775565a82936e8beba1d9
# Iteration 22000: nonce = 22000, hash = fb76a213d7dd2c893ba8c1bd5534b427db71f67299ec5e1eeca2ec95107f2643
# Iteration 48000: nonce = 48000, hash = ba1125caf97e1c1eea08379d73d95f0c19022d36d02cd83998f6cbd9e297870d
# Iteration 49000: nonce = 49000, hash = a350370b68bf3114ab2ce4ea54e6f9bae806b6da4e8d22ef61ff29268f4eabd6
# Iteration 50000: nonce = 50000, hash = eac88de0f4201b088aaada0cffac6e842829d24de949c7a6303d9ece44996671
# Iteration 51000: nonce = 51000, hash = 30f73f7365e345f6b031e1548ba948bb015105e26708d19bef7f3b0c94454326
# Iteration 52000: nonce = 52000, hash = 4325bef214e13b5c867b74416508d0a63b435650a48da8f58ab935903aaba269
# Iteration 53000: nonce = 53000, hash = 7b495599938348d954a495085d32cd9a60729b00a95abd38ed6e1fbccb1270c7
# Iteration 54000: nonce = 54000, hash = dc1ceddca830f12d6b69652c436948ef68a8a7097ca1b504d61e3e445c148bb3
# Iteration 55000: nonce = 55000, hash = e98f7abce963c8d573d688ffaa5bc0f22e0323cf92b42a81c15a21757030e62c
# Iteration 56000: nonce = 56000, hash = 91c8a28177050f6a3f37ea42318a26a2c3e19c983c399a780f6e127327b7de97
# Iteration 57000: nonce = 57000, hash = c69aa3b85db9c39df76cf1d5e210db5455dd4c8f9eaf534393440ae8d1f770a5
# Iteration 58000: nonce = 58000, hash = b736dd565a800c4f97ec97c4677d649a811ebbcd3379255cca6d6b22e30eb923
# Iteration 59000: nonce = 59000, hash = 2121bcc730a9e24d7f39b5c86771e97871cbdc74ec56d8bbca8ee16e126fcffc
# Iteration 60000: nonce = 60000, hash = 63388a698b732484e85d3ab97f7b0aa4a44140cdb2617fdd02a2301e87b0bb27
# Iteration 61000: nonce = 61000, hash = 39353fc83d6f8c9ea441e1db2c84a870ddce7da70efdb8e8630cc9d7d5b6b7d1
# Iteration 62000: nonce = 62000, hash = c1df94b0a1f2d72d9c74aa4c4219c4f5fe50ebcf4b2305cb93705f96a03b0352
# Iteration 63000: nonce = 63000, hash = 76a8994620bcc20a0c8258eb1748020339f82d35b02e308b9e8207285a1b7dc9
# Iteration 64000: nonce = 64000, hash = 1ec832e953758911277d48d430cb6b312be82bb65433a1611b609b4b74042827
# Iteration 65000: nonce = 65000, hash = 5d026f5065050c2f923a52493b2112fce69a3c7fcd1f76451380c8b2f3faeef5
# Iteration 66000: nonce = 66000, hash = f260c58d44ca2b4eca3f40b5c173f6f4f82243421abcae2bf8c691daa95261d0
# Iteration 67000: nonce = 67000, hash = 0ba493a1c7d0425816a41bf4eec4edc573d5220fafabfd7d9c21b2863c232611
# Iteration 68000: nonce = 68000, hash = c0393d15f31f21e88343903491f57798de4fbe52705c57ca7bb71108da21a91e
# Iteration 69000: nonce = 69000, hash = 78bf46f55b455c248511218352a5585841db891f46d3fd56715433a415df417c
# Iteration 70000: nonce = 70000, hash = 0964c7d798fab072002a4d8b2151905ceca01ec98842d5584e58b79383b3b3ca
# Iteration 71000: nonce = 71000, hash = 9b31fc24cdd2e2fb72f925e2c662a6d8e69f54433b92cf6d80cfe53bc5bd7320
# Iteration 72000: nonce = 72000, hash = 5e8c57bd289ceb411684269f9316f89d959c55462ebae3b8a5151e368e876666
# Iteration 73000: nonce = 73000, hash = 2022a7a3d898a85b3eccc86507006d0f387f78c1d11da7d7e2a6846dfa8bb135
# Iteration 74000: nonce = 74000, hash = fc5e020e2273ee2b4e35441a88e0374b9208d70435457135bfe24fe7d61b43a7
# Iteration 75000: nonce = 75000, hash = 7c193dd1a8a86c2ff2c733184b874ac300b214ac418d6bbf2439898615f4533f
# Iteration 76000: nonce = 76000, hash = 97403442680a37450cb2c2490d9b99b5a400d4cc1137ac1e3620982ad6755c79
# Iteration 77000: nonce = 77000, hash = d2f897423fbb3915369a1c6a0894e7577c5b5d4d1bf0be780115b16bb9347f7e
# Iteration 78000: nonce = 78000, hash = 344412e0ec42637666f662a3885d51261dcba6f03e7a3f7468502813e285519e
# Iteration 79000: nonce = 79000, hash = 09457a636a14da76cf256f93baaa366e1f9cccca573f3c01d23bd6f0c339deb6
# Iteration 80000: nonce = 80000, hash = 86dd82ff599fea38ce2c2d2eebcb45ffab119acd7c02e54bcde2e7cad8959113
# Iteration 81000: nonce = 81000, hash = 65084468611ef44f6fe806c3e608fea099745cdd64f3087b65f8459aab05145b
# Iteration 82000: nonce = 82000, hash = 02eb2f15598487a9be15ff2f076fdb9e78d3ede65d815638f4c0f3e7c00aab36
# Iteration 83000: nonce = 83000, hash = ddd9db9bdff75d3845d6809b2fc74eec15c719ff02a2d2bf31ad8b32913f0ba2
# Iteration 84000: nonce = 84000, hash = 60e5c59210afe4b7b1eb38ad9064f295479f78fa6bc7f8a7e73d5727998cbb77
# Iteration 85000: nonce = 85000, hash = 9610e942e42f9cd3d591cb73713073876dbfed438554372477560ca81c14c56d
# Iteration 86000: nonce = 86000, hash = d6926ca70c13edbf60aed16719f5a80d37784668779ab5abc647d2c64cd73bee
# Iteration 87000: nonce = 87000, hash = aacc680b4e546c0200512bf4dd6e77cb976dc6796cf725e0fc48d2babbff9c85
# Iteration 88000: nonce = 88000, hash = de88f85c80b7883ee6f91a4d4e886543972b0a537a29724ea66c031b9bcac580
# Iteration 89000: nonce = 89000, hash = 5fe048b72811f30ffa22f3794dc4c803398b1d3f71bf8fa677b39c13fa42e99e
# Iteration 90000: nonce = 90000, hash = 7a7c8b7579c598134d0177bbb5981abe9e8e42303aaee73848fcebbf1aa3ab17
# Iteration 91000: nonce = 91000, hash = bf963c91242bdad11bca7d2526080427bc23c3a49f0903dda70fc0af400684fd
# Iteration 92000: nonce = 92000, hash = d1225742cce2312ace1579a6f7a9738a4eac034ad06b2904e5932f59dcf16e59
# Iteration 93000: nonce = 93000, hash = a1c047a38a080f1229381dd0935d9da92532e71d9817f1d6509352f09dda921f
# Iteration 94000: nonce = 94000, hash = 8b44c7b25186840df67f07ea1544ab13a0e092f0c3f5743276e50146aedad481
# Iteration 95000: nonce = 95000, hash = a27c1b3e179f124cb136ee2b5cae27013f99576ffb3aee2457e822f4462dcf22
# Iteration 96000: nonce = 96000, hash = 0f469375e062bbf1d682955558b580d39d0e55dff5ae1cf78e6abca451c63579
# Iteration 97000: nonce = 97000, hash = ce9f66ba7559e216ad484fea73dc7e7a2364c9f7cf0ec51635963a2e9329a9dc
# Iteration 98000: nonce = 98000, hash = ab54544cf8d7217878bbfa9d7a0c27e2302c781fe6591445d25694f974f9af98
# Iteration 99000: nonce = 99000, hash = aefffb192c59fccb52cfe4297ee12dba6d681960eb8312e51518d82f09e45f43
# Iteration 100000: nonce = 100000, hash = 5aa8df33f737af0e5aa313d3eda1ad01775310c183320d2143e485c353da0c45
# Iteration 101000: nonce = 101000, hash = 2c6725b1f00cb17d68cbe8c99bfa2d7dbe042333179031afc9d30dff23bceb12
# Iteration 102000: nonce = 102000, hash = c039e7c0c5a82e5048b59778d6d674adbb0224f42442eee2624277612397c247
# Iteration 103000: nonce = 103000, hash = 02aa309b4d5ac6bcfd24dd9138b1cbe35203a5b8d1cfcd2a8144606fc7967920
# Iteration 104000: nonce = 104000, hash = 8c8e75811a086ef2e67099b8ee88b67174786b901c7ebbd2fd892529add049b0
# Iteration 105000: nonce = 105000, hash = f2b7176549d4a3990a1bc76b69c101294b14248109f88815cd5cdb7c0d44b232
# Iteration 106000: nonce = 106000, hash = 888642d3d9b2b0cdb56b616b9af812597fb49991a57f9aa4a29a254adf2a1c11
# Iteration 107000: nonce = 107000, hash = 053c6c8c9e936fcb2a246a77b78a5cb84ef80f16769996dfef6dfcd8902bcfbf
# Iteration 108000: nonce = 108000, hash = af19ec3804d7d676b13002b32179cd4910eb5d3220dbd67892e8818ab85c7fee
# Iteration 109000: nonce = 109000, hash = 020b3c5a3077aeb3e98fe356480dd203a660cd7bd6339a6e8997346bbd389749
# Iteration 110000: nonce = 110000, hash = 1866c6f07c5cc5ca8fa00e803cac3ffcce19bde3eee8882fd6dce7d757c560e3
# Iteration 111000: nonce = 111000, hash = e7ce5ecce7172f748c3e055f5840b23c374afe876f1884df56aaaccc9d0c1178
# Iteration 112000: nonce = 112000, hash = 4091e2ac1cc3fb04b1b9eaf99bae22247e2a3d92681bd93b1c3ef4b9a508a056
# Iteration 113000: nonce = 113000, hash = e479ad0f1036cfd35e82c3773359d11cb58b1cdcde81e95f668f79362267ebf2
# Iteration 114000: nonce = 114000, hash = cf39b243b7d8330a1578ba2d58450dcf65ad4eec4a0096f30fecc35369b6bae8
# Iteration 115000: nonce = 115000, hash = 184b5a1b66d6a115a1661cef8a457bfd50c811f3541066a5562add30f7851ffd
# Iteration 116000: nonce = 116000, hash = 9bf7c9f8ed9ff93e2e11467e2bd8fff4cec8d2565873b8a08d362b46623ab47d
# Iteration 117000: nonce = 117000, hash = fc237a68da51b5747723d88b4cc8c48791cbbb8550a14115ce206f4e74a4d23c
# Iteration 118000: nonce = 118000, hash = c8339b6a9f456821bf34e764aa8e5fe3a7ce174e1b91fcdb7860ff0d83cbd2af
# Iteration 119000: nonce = 119000, hash = 33e4b88409222aae5f48a65cb633869aeb82266ff287a53950e1b32401273100
# Iteration 168000: nonce = 168000, hash = ce3e53a98d450efbe265459e5ea7897dc93d27333c42b7dd2f846e2f9b2d8074
# Iteration 169000: nonce = 169000, hash = df7f5cd51e341372b9b2a1b0a7819cb583ad7d31b4806ab2f169009d37b730ad
# Iteration 170000: nonce = 170000, hash = 65ea4980b0edd195b96151a5118cfe785235eadec2fc5d5af02ac3c6ed3c580b
# Iteration 171000: nonce = 171000, hash = 24ef1d987a2769e9c1a690e42215c011c02503806bd3da758bbd7f66b5a305af
# Iteration 172000: nonce = 172000, hash = f4158f2228e61411871259865e0f7d57b4c2beac5f8ec2c261b1e08cd03b8282
# Iteration 173000: nonce = 173000, hash = 3c8be6c751fcd22ca7ae11e3c9dc60eef991756b5a4c704cfd1ffb713d3556c0
# Iteration 174000: nonce = 174000, hash = a970679afa12a157121155027d626add88b4d6de0507533939aa00855e12a7eb
# Iteration 175000: nonce = 175000, hash = 7653a97feb2cfc63894207fbfe6f8878c161e31d4e48b1dfc29fb0eae8bc67c9
# Iteration 176000: nonce = 176000, hash = 21cfe84fcdaabbd9c53d4bd746a7373607750b1ec007d87e9d390b48c7f6f287
# Iteration 177000: nonce = 177000, hash = c5b3b7bc842ab9d1c0a66a49bd9b2aac910d6b2c7e3b0ab66f51298ab8728689
# Iteration 178000: nonce = 178000, hash = 4aab58ab919795c1baf23f103eae347b202b9da6b9fa0ee3b84e0299f6623e9b
# Iteration 179000: nonce = 179000, hash = 6a5bf5ea54883e2382460377eb25926903c8dd08eaecb211935adea16a3b0a22
# Iteration 180000: nonce = 180000, hash = 4bde84c11f6a24080fc450123514bcf11413b8e50f2681edabf9628110315329
# Iteration 181000: nonce = 181000, hash = 261554f516c001dfc6d1e149aec5d7ed6d382ce5c75f87297d32e74cf04f2bb8
# Iteration 182000: nonce = 182000, hash = 7998a25dc9d9cf7a159d36af6aba78c17c8190ab53b70a57de2e4269bb1c888f
# Iteration 183000: nonce = 183000, hash = 790d2b96bc8dbc224376db626d8861bc5b77d95c85001e4599c6e3f132f17fa6
# Iteration 184000: nonce = 184000, hash = 9272a5622b326a183515f1b6b445f5c53741dc8179a815475bc1e805284e970a
# Iteration 185000: nonce = 185000, hash = df4fc9351d265a716736a8fe85edc41091d6a9ff1b4ec619a7e6db60fd607d8d
# Iteration 186000: nonce = 186000, hash = 09ebe06ad2754b6c3d33fdf5e3bd3cd924d04f039ac1bacd620bded383b37bd7
# Iteration 187000: nonce = 187000, hash = 30a1b47ff6ce5f47f2055f5ccff3dc8077ff50c6075f09853d2c5637102e9d78
# Iteration 188000: nonce = 188000, hash = 80acdd6364a51af6feeaecb569a26f9500be9f3787df77c5ba4586642e6f54eb
# Iteration 189000: nonce = 189000, hash = 86342653cbc04eb7833edad9ddb84c636555b363ecf354568123acd2a55b5ddb
# Iteration 190000: nonce = 190000, hash = 4dd5ced7a9e7c9fda3740c7468f7489f7d07ba4f9ac382dc9f370f029e73911a
# Iteration 191000: nonce = 191000, hash = 9ffddaf304f9acefe854be27095ee14b8689047c2cd858bfbe68c543c7b20cf2
# Iteration 192000: nonce = 192000, hash = 56df0283e74fd88cc9a5dabfd43e167e88b940c8864b341873840832fb626c32
# Iteration 193000: nonce = 193000, hash = 0371ea36c51c978f150740d088fc99a41a71f3c65fcc6d15a404ed67de6ce5e9
# Iteration 194000: nonce = 194000, hash = 0aef3a597523b72132a03c9aa9fcbe5a9cbd5cf9a29b76e0e069a7fdbbda9927
# Iteration 195000: nonce = 195000, hash = b122721c69469637d40e97c556190041562d96e8a38869a048dc40530ee9fcb2
# Iteration 196000: nonce = 196000, hash = 9847cad6a944958f099952c9065c1fdc42a6b0a8f1713445c263cd45f6a32ed7
# Iteration 197000: nonce = 197000, hash = 92adf7232c378bced97663f75bf8090f5728e72b00dfe55d2285b60dfabaae2a
# Iteration 198000: nonce = 198000, hash = f3eb397f5bd56d4e7829872b6d330e7269ece6f4126d2934c0aec40d8563330b
# Iteration 199000: nonce = 199000, hash = b43e8a54c6b6936b6141dc6574da4a16eabaa7b6dc69b7d3ee78dc994b6c8271
# Iteration 200000: nonce = 200000, hash = 3f1e18b2065fd77b7a306b3626c691bb2505a107fedd3c13c7eb0646a530f30e
# Iteration 201000: nonce = 201000, hash = 747c18ca0cfb9d075cc6011dedc5f651f605075d47525337297565bf5f9b188f
# Iteration 202000: nonce = 202000, hash = b025c5f4e3fc2fbf25349da681ac04dbf9bd66a29c2fa4942295e7ad7a4a2eda
# Iteration 203000: nonce = 203000, hash = b19e278b0dba64b014e3757bc249b117f459127f6460ca051048c97c1eaea150
# Iteration 204000: nonce = 204000, hash = b0fea5d9f07d7d9d227e4f0c97e118943453830ddb5dfa1fd5672c6e3e705074
# Iteration 205000: nonce = 205000, hash = 92958b4c07ade2b00dd3a90f69cf5d7ca9ac4f5b633ab20e581e1316f303bd65
# Iteration 206000: nonce = 206000, hash = 34af57b3701b08a29347542ce728a5eab9b6dd122105f559cb3e5a95949dc0e5
# Iteration 207000: nonce = 207000, hash = 618176208a826362094ce3aeb5a925ce5fd922273c2f65c072928677c922abc2
# Iteration 208000: nonce = 208000, hash = 1ee66cfe4f8a3ada6e11a3407f395ba36521766d08c717091d862de2ca4ec684
# Iteration 209000: nonce = 209000, hash = 6493330e941af384d1ce601fe5290ef1410559b257415a42dc47778710c4746c
# Iteration 210000: nonce = 210000, hash = 66375171a5b630152bb1f2e37b72574775eec91b4c59ccc6be3a40a1d6ee12ab
# Iteration 211000: nonce = 211000, hash = 12c91106230fa98943cfb8c638fca742c88847590f516b5066a1264be3e7379a
# Iteration 212000: nonce = 212000, hash = c07c4b1cf24a71bb2c01cf4e185d101ef78c3df4a8d33b556ededab17ef59756
# Iteration 213000: nonce = 213000, hash = ac10f1a149e5b59375e8333f427325ca4accd92fb243729f1442c278da2c1b13
# Iteration 214000: nonce = 214000, hash = b3d44c4f51cc290298885be595feb6a7e88e4d39a418c6eaf9ebc56e22ff504e
# Iteration 215000: nonce = 215000, hash = f4976526d4a3ca980074168da736c422012b0b44510a287d7b89836aa2d96d53
# Iteration 216000: nonce = 216000, hash = ee3ff641d50f9c2bf9fea8a58b783b0eded402b4e3f2299c6a672dd14021d139
# Iteration 217000: nonce = 217000, hash = 3921ebd603402132cacfea1dbe55b668d43eb127e554faf4da6cdeceb79be719
# Iteration 218000: nonce = 218000, hash = 3dbb230be281ceafeb19fcfc0950111ab8606a0c315a72cefcd453bcb7927e6f
# Iteration 219000: nonce = 219000, hash = edf0cec3062baa6315e62a73ee198f5356090261959ee876595f6af6aed74706
# Iteration 220000: nonce = 220000, hash = 75ea16d31ba47ada0d9fcfeceea940c5f18fbfa657f82068176c39678b11aebf
# Iteration 221000: nonce = 221000, hash = 1f11993d47c2483ae84724e4fe19f8606daf00a918f1b20507ca8331d076ecb2
# Iteration 222000: nonce = 222000, hash = 11934c47374d8a6a3201e44e84b26597e6ba6cd0cc4647fbde258fea26a2497b
# Iteration 223000: nonce = 223000, hash = 5f4638fc14f9946147fc9835cd9ab99c5ba3927bb7a22c7ff6c378eb0465c6b5
# Iteration 224000: nonce = 224000, hash = ffd2f947577eca7fc98a3ed6ce1850866689de5d8a33a87a459f1a5f6ad35611
# Iteration 225000: nonce = 225000, hash = 9c614263296bc67f39d4e9b09037ab2a3c9dee31d2d5fe1b37bc2bdff72050bb
# Iteration 226000: nonce = 226000, hash = 17fa106340aba9e872616c5dde3609d18a82e6cc53acda784301590c68013c6d
# Iteration 227000: nonce = 227000, hash = 9867a8ad0b8d62a43c58b36923edaaf149541bb36edc404f948514b9b8a23657
# Iteration 228000: nonce = 228000, hash = ccd06d1ea851c7180a8fb1c510e4a8d84014388f6978acc3c9527701b71fd3ef
# Iteration 229000: nonce = 229000, hash = f748d795bd00c3c691722c866446308b277a7025a1ea1bbe6e5cfa144aa65484
# Iteration 230000: nonce = 230000, hash = 02fdff76f3e8ca18141ef7f34683e27c3b8b940c05527717788d3302de43b034
# Iteration 231000: nonce = 231000, hash = 515a4d5b876a6767f531bc11e7d02e1ec484348e477f7def37e5e0846320f1ab
# Iteration 232000: nonce = 232000, hash = 27e4b22f6effce118eb6b753b5a9fcb2ac858eee0232a66efac84c91f8f374d6
# Iteration 233000: nonce = 233000, hash = b031dcc31ccd4d7459262aee8d474826a5b255daa8d27c0ae82acae395ac26c4
# Iteration 234000: nonce = 234000, hash = b21167e546af98bc0d0209ce2c39b894e1a45cbd903edf6bc5bd1783d491453e
# Iteration 235000: nonce = 235000, hash = 8816410bf801cdaf373854f87ade962c8e494e204293a5063658ba7f61f8e4fa
# Iteration 236000: nonce = 236000, hash = e4f9b45fbd253773ad7facf8a7607e130b2bdaa6e526055280f5e1d18556334f
# Iteration 237000: nonce = 237000, hash = 98f5b5db2dcadbdae0097646b4859a3bf751c6d5fa37dfd14c8769ba5ed1d9f0
# Iteration 238000: nonce = 238000, hash = b0c33e093a6b5eb1f815fb4371f8c56eab514805bc185517c52aa8eeb0e9fa00
# Iteration 239000: nonce = 239000, hash = 168daa5c3aeba96537ee43b002738bae3777f432ed65a907e981030f15fe34e4
# Iteration 240000: nonce = 240000, hash = 3627bfb9539f2f53b6db780160182640e644d22e6a7ff66c1d7dc492d0a515a1
# Iteration 241000: nonce = 241000, hash = 2592fec9f1fc937da3a614521eb295b7a6008acd9dd5f9a691c23299b098bd9d
# Iteration 242000: nonce = 242000, hash = aa7c901e0f0805ca1d3b342e52d76a508e219945234ea31af3e2f31ec33d3504
# Iteration 243000: nonce = 243000, hash = 9c32543c9618b90253d11f2b6b7e3f514760c1521b3a936f64195998e5b68063
# Iteration 244000: nonce = 244000, hash = 362397b0c6e1f3aa88a84e8b26296d83b464dfd726b04b044bc784e426dde616
# Iteration 245000: nonce = 245000, hash = edf1a33ae1577033e2f576a81373093d461c226d8765791e25e0d597fa753600
# Iteration 246000: nonce = 246000, hash = 8291ee8be4bc10f0c6e565216538a2d0d3ccf4c2b6107e7b323928990afe356c
# Iteration 247000: nonce = 247000, hash = 4335efaecb3def1ed151f170e790f6167234c972c4ac10d3ff5cb959147cd78a
# Iteration 248000: nonce = 248000, hash = 830a1fc72d57ad114b3c347360b567b5db6830a3b8c1d31532bea895eef1f4e6
# Iteration 249000: nonce = 249000, hash = aadf6cc500898fd52f0318770dfbe09c43a45f1f8313642af44003159a573fbd
# Iteration 250000: nonce = 250000, hash = deecbcc3cb2c175c6be9ba951fccd9b20e525497e70301e8be0c9a8aea423cf9
# Iteration 251000: nonce = 251000, hash = 3a130f784790e9bd415447903c8a8be63ed06661bc4291f80c3280e9a2b9fc2b
# Iteration 252000: nonce = 252000, hash = 9e11d4646a2df147b89551cb0d9c8939c4d50fcc26051cbf65db60272c22fa0c
# Iteration 253000: nonce = 253000, hash = 2d86a21c800ea82d0cf162faaf0fb37727c7910981c1984398cec977358294fc
# Iteration 254000: nonce = 254000, hash = c8aa42871745e522485771d5eaa6888d8167d5e547de1229df1003d030da6d75
# Iteration 255000: nonce = 255000, hash = 5eb425b016b3e7b0484073d0e0b76ad863b5b2a1fdd2c77ca1fec26dbdd3582a
# Iteration 256000: nonce = 256000, hash = adce69df3334838baddf73733689f55c5ecb623114ae563230b6bb819b1cdd19
# Iteration 257000: nonce = 257000, hash = 17d600e6fe4e6ae100056c2516047e1925a43ae46cd6ef57a2d20daa670b0cf8
# Iteration 258000: nonce = 258000, hash = 25482cead1bdfffa9e7970cb9f5edb7ef76b1af6d044214560c7b2eb34ab127b
# Iteration 259000: nonce = 259000, hash = 07705dbe84ce148abc6034bb5aa40253ee2c54aaa271552bbd84db8df45df8d0
# Iteration 260000: nonce = 260000, hash = f26f8c306eeec0b0947478eaa373ea40be1a031e4df6925946e1f6b59339d3d7
# Iteration 261000: nonce = 261000, hash = 63c8aa3cefd150bf1fc754e7e278e7de8e59c4bc0a213d33cbcca6450e05bf45
# Iteration 262000: nonce = 262000, hash = 6bff890a53529513daf7b014edcca6987c15ee5672f2634371e540f475f14b67
# Iteration 263000: nonce = 263000, hash = b3ab273adf4a2db098cc5e74335b527e4c782880cbcfc4527c78f0284fb5c7dc
# Iteration 264000: nonce = 264000, hash = e354223c32a3ce57de9d7337a2e20ed5b2019a9161d163def82bcf6fdee22d9f
# Iteration 265000: nonce = 265000, hash = 57084316e5faa3e8b5b1abc9d21c94dfd54c96e25587e7022b9af41aa1a943d7
# Iteration 266000: nonce = 266000, hash = d74038e0aef4f8d0654e147250050cb0042874fc3d651d188cba9b9effb4a210
# Iteration 267000: nonce = 267000, hash = 6d32fdb1f728faf6ab598d0bc0f6154a6ac8cf3c2a504b75f82decf5c355bb76
# Iteration 268000: nonce = 268000, hash = fd48bcbbf4d670e4b1d3e354f06d5733bb19706dfbaadc38bb8f3d0741f94671
# Iteration 269000: nonce = 269000, hash = 439cfe9fb113ce2d6e319c9013ecb0788ee74bc4c700075ad1fd26a58c8827b2
# Iteration 270000: nonce = 270000, hash = 24c8d8a413677852aa948ded0fb48ec8e838cf897231d3352effd9ccfd861e86
# Iteration 271000: nonce = 271000, hash = d8c29a80805fa77f4fb128ad2017e95b0c6016ecb4e10b7c94539a68f225b289
# Iteration 272000: nonce = 272000, hash = 2f18b1fffccaf4219ced9972a164b6a489a614677b52bc640a703992dfe3328a
# Iteration 273000: nonce = 273000, hash = 6bd87001f5553533046c875f1bafe6dfa7cc1485b20d7ed6bfed7e5824fe65d9
# Iteration 274000: nonce = 274000, hash = 44ea01a942b439d58327ab1521957ee840099a1314327a7e4873c910f9858f25
# Iteration 275000: nonce = 275000, hash = afc7663c5bb1b2c3da2071a6f2b80947388e5bc65da20f5bce67edb02719fb21
# Iteration 276000: nonce = 276000, hash = d9ff6a316ca185a620b8731b0b68770a74682f997825a7a799f6ff6571664586
# Iteration 277000: nonce = 277000, hash = 8c1d1118a9b089297ab641707451fb46a2a60760004c9efce90a6c8b6112a498
# Iteration 278000: nonce = 278000, hash = e9400ad7a0cf88b5b63e922d84f44d976ec931f04f7487aebf287ea52b0d43be
# Iteration 279000: nonce = 279000, hash = 1938c83c1df6ea23ff55cee888c13b4fabe0b9d7429ffa37c30d09cb0b4008c8
# Iteration 280000: nonce = 280000, hash = ed7b5a43232cf3dd4401cba34d75c277855dcb21dc63be9d0cc6fcd695ffb100
# Iteration 281000: nonce = 281000, hash = e666b6fbf3ed07c61a09b31ccdc376242caaa33084c1ac432e3ae72ef99ad447
# Iteration 282000: nonce = 282000, hash = ca046aa559ae81f0d1b330053d67e376507c54ecb9430e6a27560f7f0dd8957e
# Iteration 283000: nonce = 283000, hash = 28e8c3d3bbbd903063bef103a29310d7f07f5292768a9491d1e89600c9403063
# Iteration 284000: nonce = 284000, hash = 7702b03ccd19707269d59d8fa2634fcbd7efcad5945030a44168f1b7f153bff2
# Iteration 285000: nonce = 285000, hash = dcd2f160fc3c55d863bc4d5ccacd10cb73d1ecefb26dc7c51dd49a5401abfbb1
# Iteration 286000: nonce = 286000, hash = 71f7ddd6aebffb978bc135e5e65c30d2433a50805b0141a2981f033347f2af20
# Iteration 287000: nonce = 287000, hash = 30de3b74f5909f88f2e2d70253a1fbcede7fe9592b5945ac2d0cab8a0ef99092
# Iteration 288000: nonce = 288000, hash = bb5bb9ab7664696686baf8eb3ee518823c2050bd89cce829c6aceec14afd34c5
# Iteration 289000: nonce = 289000, hash = a0d0ebe2277d18c887d62e33b7fc3c1305c94385845b1b7b2cfc3215054eadca
# Iteration 290000: nonce = 290000, hash = c8be4cc28b5151c06a8aebe7dc016e8bfd61c4d6b97ae0a5f6d26228c47b3587
# Iteration 291000: nonce = 291000, hash = dee17b6d54fa818f1a1fdf1b4a4af8c1f8fa4fe93ddb3083c15383b1d5d1bf5f
# Iteration 292000: nonce = 292000, hash = 8d4b4aa4ce676a4823579ab261ec7e01acbf5642deb1a6cb04e31812976d78ae
# Iteration 293000: nonce = 293000, hash = 77b44e01b94357cdcadc08687f6c21b4f86be1cbba83bf5ff6b93b32078c5fb2
# Iteration 294000: nonce = 294000, hash = 8fe9cbd3238a05b6bdbaed27556a5bf75a2a3709083e67fbc875efaa26398b59
# Iteration 295000: nonce = 295000, hash = 217118ec81345ecf9127fc22774ffee0d3df533b36113a068eefc27f7219b7bd
# Iteration 296000: nonce = 296000, hash = 83340d335e33deee59eaf38f581350479e9d475f7047430743018989a43272f9
# Iteration 297000: nonce = 297000, hash = e95b74349023085961295d0abe62b56f8ac58e3f4bf043ec1114e2457d5aaa57
# Iteration 298000: nonce = 298000, hash = 1b0c7766c78f2d4c9fdd7e7449abdc35a61df6381146b28828b72f60f55fb9d3
# Iteration 299000: nonce = 299000, hash = 118090f93495b59601af3d4b63e4cb894fc61755a8fc3c5c69253a51cff76611
# Iteration 300000: nonce = 300000, hash = db11ea0ef4892faf35e248f2f28f49505ae5d7c72582d16ac4d84b692d32710d
# Iteration 301000: nonce = 301000, hash = 27fd80129f3a0dd4dae2d1fba0e37f886bbf4627deb1f96c3c2e637a1fb42512
# Iteration 302000: nonce = 302000, hash = eb0e0427f24e6363a69fe332b6bdb808738556183b9fe7506a311f5f886601df
# Iteration 303000: nonce = 303000, hash = 53d67447f8b6a44b460df4ce0d6a3d4ac777c2bab04f043b2da6dd0fa2166c57
# Iteration 304000: nonce = 304000, hash = 91c49c56c7e9139f771ebbddd9d5c5019f6257ba9cb2bc84bf690b48191ab940
# Iteration 305000: nonce = 305000, hash = bbbbcf69bf2cd38fe397082e7bb6d645e8a022d3596b328fc23ddbfa0a00ec38
# Iteration 306000: nonce = 306000, hash = cf43830e5a3afc9683191d2052ee65ee5d64787f1a511320904d6ccff3e92375
# Iteration 307000: nonce = 307000, hash = a83c00d03d181cfec3373ca50c518aa2f4a1486db63bb216b980bcb892a5c70d
# Iteration 308000: nonce = 308000, hash = e1d82b9e88e96bae95b39002ee11778068baa7dbe3405c6a38f91505968444ac
# Iteration 309000: nonce = 309000, hash = 6f72256bbfdf21e0fdd4af8c977befe6ab6c8a62d6536d906af9e987d7869b83
# Iteration 310000: nonce = 310000, hash = 2afd02d3b9340fea355e52a3d3b4dbaf861ba94d2e6fc31682f83d43974451ab
# Iteration 311000: nonce = 311000, hash = 9d5ee39bad7018ef658aa719ea510215c6e426de017752b9cae19f8bca5e259b
# Iteration 312000: nonce = 312000, hash = 3f1f6ae817a8231cec7eecc9cefb9fc40a35bacb9271251ba4ed999d5b5b7840
# Iteration 313000: nonce = 313000, hash = 2930d8ce08096b72d4d8c57ccb1cb723eede8955befd5f1c1f8865b9ee73d247
# Iteration 314000: nonce = 314000, hash = 0a3817377b6c8b80ce9f9d1cd69447f715b41ee71e95f40a8e3df9f4f0360538
# Iteration 315000: nonce = 315000, hash = 4ab7d0f515ae20482a8849dbc3b7c3d8d264044c75a4229851840bdbc39a2c91
# Iteration 316000: nonce = 316000, hash = b1782df3d0a7ac532ac9dd556ab02ce63410c550a8e826c21c1eaa987864d0b7
# Iteration 317000: nonce = 317000, hash = 1021435155140eb9af8644f4b615ace7af162e95ccbd2572b0d7f8ebf5e95851
# Iteration 318000: nonce = 318000, hash = fe7f2dc2a92d4abdaf25d64eb7878d97dba1363f4913aa503b1b0cc9bf76a3bf
# Iteration 319000: nonce = 319000, hash = 7fe6746d87334aaabd83393bb2aee85643c2051978ebe66604f1311c9d8ab20c
# Iteration 320000: nonce = 320000, hash = a8e3d908e23ac28cb23084dec813f2f3cb5ea02b27983cd054543b2d5ab6334b
# Iteration 321000: nonce = 321000, hash = c7f1bbfb7ca8363f1f2d2550fdde29b1c03d657565179bc5f580cfef0860d53b
# Iteration 322000: nonce = 322000, hash = 37e1feb414d4bd3e04529ad53bfe8a064548a7ae8902e6f6dc04f42c390e1179
# Iteration 323000: nonce = 323000, hash = f078fe787ddae68c5878d627891a69c7c6038d930d8e29df43d7cc860dccbd4e
# Iteration 324000: nonce = 324000, hash = 5d309b86cb1746cda044d8e92bbbef15bf53833cd745fa17809a5cfd92774038
# Iteration 325000: nonce = 325000, hash = 1cd34dd6f02660bc78c9ee14236557c44affea1e8c1faccf1d5985b62e26ab27
# Iteration 326000: nonce = 326000, hash = bec311ce8a318e9ce1cb84a3051d447b38927dce8b5209a73b67bac69d4ee133
# Iteration 327000: nonce = 327000, hash = f25ef9417b8ff4356502cf0473849f888ae50cc39f2a675655ad4e8fb0b5a387
# Iteration 328000: nonce = 328000, hash = e8c777ea3f93148756d8e1928f05a2ff78bbf9feabfd9c75dd1f76b7e4f6ff01
# Iteration 329000: nonce = 329000, hash = 4262631eabbad890b0976977a6a35599ef4753d42ab121535e4d3772a16e37f0
# Iteration 330000: nonce = 330000, hash = 1be0dcc7fd37ae5ee6998ac86fb2977955dee4d3d460d971e61bbeb9a497c1d6
# Iteration 331000: nonce = 331000, hash = b11088d93cdebaaa7c10320b73217ddbdd43d9ee403079c1674e8867768ab6a7
# Iteration 332000: nonce = 332000, hash = b33a96a10ea4143ae1c96e78c8af91b70933519aa02f6a98f8ca27c932078e08
# Iteration 333000: nonce = 333000, hash = a59d5bf8281f925c1266e10bf5a40a687473262838df3227c022bf38d2a1a46a
# Iteration 334000: nonce = 334000, hash = 55568307074c5f2463d2c5f1c8cf427e21c3b04256eb163a86a3c539b73a0aee
# Iteration 335000: nonce = 335000, hash = a8fe5ec26f7ddec4123fe3e7fab961c4accfd12f746c24552a7cae7d213469ea
# Iteration 360000: nonce = 360000, hash = da283e2c90fdffa3c6f54a307cd321e7dea399e2c56d32de88197a36c3811ab0
# Iteration 361000: nonce = 361000, hash = 596e8b3e2a615fae895b3565c0f7b6d746b1ea423161f9748833c38d2bab40f2
# Iteration 362000: nonce = 362000, hash = f5b07351cfb5dadc513d1f686f7fe67a546d1c48695a82ac65dbab222aa59504
# Iteration 363000: nonce = 363000, hash = d642c21c09b6f795b2708cf81476da7c7e9c3188b921c2823f56c79374832dfc
# Iteration 364000: nonce = 364000, hash = 2db62ea83b17f55b7ed48be5a9c3f20611e3ba752b413d847b689051549a3e1e
# Iteration 365000: nonce = 365000, hash = 79ebe05dfcb6355253bc8de75dcd05873691f3f057523decc6a963c124a0678c
# Iteration 366000: nonce = 366000, hash = d29ca7e08d54ec6b9594259c3d4435bb1ba4cf02a3452adca07c49e75cf42772
# Iteration 367000: nonce = 367000, hash = b8302d3c9a05008215968634f753adeae531372280aef60eabe4b2bb894356df
# Iteration 368000: nonce = 368000, hash = c00530f30904acf7b209a61e695ef3d0563548820059efba0e1c86df7d68a5fb
# Iteration 369000: nonce = 369000, hash = 5c5625c5c5df675800a34b58915df80598a1d548d726962800afbeb4542aa417
# Iteration 370000: nonce = 370000, hash = 712d58030377f13600a900684ce7fa8536ce3163d00f66c111cc8fa27dd65864
# Iteration 371000: nonce = 371000, hash = 9da5d626cc343c5688e6e961dac18a3fba0222b5301d4eee13591e23ba6b8594
# Iteration 372000: nonce = 372000, hash = 49c4d09a8bd2d80700789f8e4f71415d4cc764dc8faead290113fc2284c76e4b
# Iteration 373000: nonce = 373000, hash = 3541a0d0132decceda9a3e02014409c2e4072d4496fe443526718ba3224b1178
# Iteration 374000: nonce = 374000, hash = e0ce2ed75e60c0266a341a13c0c9d72d8590c76cd0b5602fd7faa58574d6c81c
# Iteration 375000: nonce = 375000, hash = 9f7a5a8ac308a652006a096de4cd3817658227dc7cada84f444610f78e73f5b9
# Iteration 376000: nonce = 376000, hash = 98d8a81f25a3ed82511e7c0d3b0dbe2a08c0ae018ae6b27f154b5426bdb39e32
# Iteration 377000: nonce = 377000, hash = 713877934788d272d7acd7a6e29da97fb67505c63fa35041611bca0e38a75c36
# Iteration 378000: nonce = 378000, hash = 14b39e41d52eed771c47296de799b8091a9952decca71ca085b6a23bbaaa0d19
# Iteration 379000: nonce = 379000, hash = 16dd5dcb4b209d13505ddb9b8f3b565083db7e5cb25504c83d56a0355509a2d5
# Iteration 380000: nonce = 380000, hash = 49f92c13f09ba390854828d18108422efe7ba1d55b3ef72a202aca51ec4e6b06
# Iteration 381000: nonce = 381000, hash = 29664c45a43d9ab31dbf2df7030602406b15668435d30cdb5cce65e87dac0741
# Iteration 382000: nonce = 382000, hash = 03cfaa472e79f841983e9ddf1a9b0d863af2862e0e15e2e9047adaeac6abe176
# Iteration 383000: nonce = 383000, hash = b124e2a590933435d248bfe1593e207e8ba5219ac5a6673d5cc474eb2423d0cc
# Iteration 384000: nonce = 384000, hash = 801090c445fdcb77187b848c4c0bb2092dad8bdc852d4dbda6b98ac097c0b7d9
# Iteration 385000: nonce = 385000, hash = 356f209a1623801ca09bb3b5c364796d9f1fd2f92388d4a7590a460b1136d63b
# Iteration 386000: nonce = 386000, hash = 46ba0b45e5a0f19d52dc34e6fb6af3c183d0b4633ec8baed0fbae835155fbe82
# Iteration 387000: nonce = 387000, hash = 18222568b35c559cdb62a47481658a44f3d951d6b9e6b35963d083f292d2b77b
# Iteration 388000: nonce = 388000, hash = 26e1c532fe5eb0a39b15eac592d74146d90b2234545c4d34e5167e1b0db98bc8
# Iteration 389000: nonce = 389000, hash = 3eebb73ac4680fef54abefe8d6952e157ab583b587ef5847761046ad30628bc4
# Iteration 390000: nonce = 390000, hash = 05565e3cb4cc88a569b61edaa10db4497fcfd6b364998824c671c1b9bb3d1f61
# Iteration 391000: nonce = 391000, hash = 42637b390be5fa3171f5b2af5b0074e52febf6a23f27f2ddf91f6dc3c96c1a30
# Iteration 392000: nonce = 392000, hash = 78497f47372fceb66e34fd3f3f8ed1fed9fe69c409379d0c2c265dd7c4a507f0
# Iteration 393000: nonce = 393000, hash = 29e389c351e6788d0cf1b05ac4610a2a6cd01686044e00dbc2704024d0b4482c
# Iteration 394000: nonce = 394000, hash = 03d3a4ac14f6d3ab5f447b55247f823c2d2607e4883333ce651fb511ba02f536
# Iteration 395000: nonce = 395000, hash = fe431a124b899754b793020fa7af846c69ff01a026b66c9eea873c01db3310a8
# Iteration 396000: nonce = 396000, hash = 37fe8e4adda8e79e3787a984d492eab2c082ebe33039fc8d6b5b67e888542916
# Iteration 397000: nonce = 397000, hash = 4427ecc7a105e9a876f0897d15580c5ae8516d5f7d9c70893e16c24300f4d1cb
# Iteration 398000: nonce = 398000, hash = 610617fc72d2062a67ca16ec1d9329fe483f24b87a3fba756dff292dfb1dc08a
# Iteration 399000: nonce = 399000, hash = 28039a7e97b02c497158e1cc72441a48b1e60ab48c70c79481acb0635756e8d8
# Iteration 400000: nonce = 400000, hash = 7ffd9245bcc7e92472971583ea2ba91d2ab891812932373461539ebd7b69047a
# Iteration 401000: nonce = 401000, hash = b2b4aa43d5351db6a2992619d69d97b04fc014491fe14a00875a67c7dd14f1b9
# Iteration 402000: nonce = 402000, hash = a9b9e2bf8e54474a2d685aea9f767fc9e140250fa70f394e128980de1a38762d
# Iteration 403000: nonce = 403000, hash = 058786af71f3139e34f3789c5fdf61f093675faf4464ac97b5ed3f1b441eaf45
# Iteration 404000: nonce = 404000, hash = c1f27b9c1062872349a5dd73d1793800144d9e94895a2836dd77619263468998
# Iteration 405000: nonce = 405000, hash = db6138c1ecf1541a8a4f13f978f0eeda3699fa3c090526c2fa0c46881e9ed50e
# Iteration 406000: nonce = 406000, hash = 075b450c624021bf2b964256ec9e01b3c7741999d92e9bfb2ec1dffbb98bee8f
# Iteration 407000: nonce = 407000, hash = e4c36c147e2045cfa4d82ab189652353377db684ee4d1bccf310b482e932de86
# Iteration 408000: nonce = 408000, hash = 2f52856f3cb841ab3006ba8c447b5c4f3b77993a8bec613f69bfde75af398c71
# Iteration 409000: nonce = 409000, hash = dc0e009c06fd4610d709039a1de5f118639f9042bffcd3ba1f7679a45f782d50
# Iteration 410000: nonce = 410000, hash = c11e52c3e4e39fe0aa4c57e931fb2f967fe1b3200f1f7ba9efd20d8b561bc489
# Iteration 411000: nonce = 411000, hash = 1e1cb0e165549fae7b2a7eced9d3707889ff0d351bcf0504125da5c860c66d9c
# Iteration 412000: nonce = 412000, hash = 120836317dd69684a0f517eba27dba055b5865de7ed96546070b6c6691a39deb
# Iteration 413000: nonce = 413000, hash = c0e24760c4f6a04ee6d469960ea250ebeb19af44d8f0d18840d4db41b1126923
# Iteration 414000: nonce = 414000, hash = 536224c27b06cdab86d4c3809fb5d57499063121acd69f9451db4577c3a4318c
# Iteration 415000: nonce = 415000, hash = 2721a56de70301295dafffc5795f285d3fa427988bc038a8bccad6e41b22ddcf
# Iteration 416000: nonce = 416000, hash = c3e7ec41b923663d5f549b32e1eca42e263a4767e68addefe03f261301cce716
# Iteration 417000: nonce = 417000, hash = 94d5ff6cccf8f6eac9b8319190d2627f93defc2b3838bc2a061ea7f43a437106
# Iteration 418000: nonce = 418000, hash = 35c15a06eed548a2e348dd23548046d39697e5453c8c091c618ecd86f2ead28c
# Iteration 419000: nonce = 419000, hash = 725f393d4aed1b51e0767107f59a12ee4ff841bef1100e2e77aa4a02ea6e3c7f
# Iteration 420000: nonce = 420000, hash = 1f1b976e6cf5ab2b65707e050b46b77012ad05f5c913cf5a4d270ef1357d5ffd
# Iteration 421000: nonce = 421000, hash = d8443e022a65566291fa7fb5c22a8f6e496d6210442581f272c7b1a15ec8b6a0
# Iteration 422000: nonce = 422000, hash = a6c0884692ca963d8a9f3c98dd421378531a86d03cf92f497c7256b93fc91d3a
# Iteration 423000: nonce = 423000, hash = b9ee62c6772d0d2f493e89e197d68f5f81960735a1d1b1d3a02130abe0dd7559
# Iteration 424000: nonce = 424000, hash = 5effd46b6b6ea00653f58c16f2ae3a15d149ba8e922dd9791f9d53f648226ec4
# Iteration 425000: nonce = 425000, hash = 70a2cf79650cf6023f9ecdb97744a21fcb8e9e56e225e0e2cc46f4971d0861bb
# Iteration 426000: nonce = 426000, hash = e68ab681b73ee3420f268f4cc69ce5dc919e9c809f83c102c782e071b4e19fda
# Iteration 427000: nonce = 427000, hash = 3f4ed4374b185e1b0becc8844b9b491366c9759f491ca1fb5212ecc2dc1d44e2
# Iteration 428000: nonce = 428000, hash = 7115e8c8935ac522bedb30b16f3dd01f38d3f72e7dd6e94c61660dae76a8cea1
# Iteration 429000: nonce = 429000, hash = 6ae859a85eca1333c8deb2e4151d9f2a4f744ff7a0de85ea8624994ea9168d0d
# Iteration 430000: nonce = 430000, hash = 9c38009a26387f5900a41fcb485faff1bb603d0ac6eff26a068d09fed8a2b102
# Iteration 431000: nonce = 431000, hash = b241214ae476ae4f9cf45c24ab8cdeddc5139afe32647f98befdfd5705aceab8
# Iteration 432000: nonce = 432000, hash = 6d42846e989bd674c78efbc6d3c639fc982a398f5d5b74aec3dda56b89c68482
# Iteration 433000: nonce = 433000, hash = 11901a43bb3222991fa013018b4a1bfd895f01070e6a598642b6d808a05b5f1e
# Iteration 434000: nonce = 434000, hash = 34f53a72e6d1e77f8b84b9bdb4713413f23d708c7bcd0f3ff385e5f7d61ac55a
# Iteration 435000: nonce = 435000, hash = f8e6392935ab8b488aea0bb956c99f494ce213f6721641306cf738dfa24cdb9b
# Iteration 436000: nonce = 436000, hash = 463b2d170d1fce62478227c37185133cba456dd9916fa4d1a8a1bec27a87c41e
# Iteration 437000: nonce = 437000, hash = 16edb57974d9ffb9183dcc8a4c8e2dcd9c4fef63135d371145d9abc08e55511e
# Iteration 438000: nonce = 438000, hash = ed34dbc7af5173f96258d10ce31027c1c55a889dbc8bbb814c382c45b713b110
# Iteration 439000: nonce = 439000, hash = 8559de89d4e40d026367bdd098303863ea6257e25c63464599eb4d9ad182c226
# Iteration 440000: nonce = 440000, hash = 34c4187baca5f3e7574ff537bc484046bb6d14dd3dd5947b902f6bcec0533daf
# Iteration 441000: nonce = 441000, hash = 3c6edcc346b7b952f8032eb7a5e600f265edd33848c71303fdc078925c829916
# Iteration 442000: nonce = 442000, hash = a4f821351830f0af65137171e0b625b16e5bfed74d1d28b25e6034b281a5c4c4
# Iteration 443000: nonce = 443000, hash = 260f64908e9511386e6cdb5b07940ede92b5fe16e16b178f4c52ee052bc48ce1
# Iteration 444000: nonce = 444000, hash = 027ea005a4260ad3b4d440304c374b114d82be70a2dcbaa97de5a914f04b35d6
# Iteration 445000: nonce = 445000, hash = 30115ff960143c88404810b12126b96b5e5dd146596f1b7a1e9d0d5f753f3e4a
# Iteration 446000: nonce = 446000, hash = 3f4dcc143849904840980316afaa6ded6b59122f5fc58d0376e8bb2e8e96c62d
# Iteration 447000: nonce = 447000, hash = d108ebab80d6beaab5258b257f22290ca9713db77859cd6324328b40a179e49e
# Iteration 448000: nonce = 448000, hash = d31ea9661a51f78dcf3b9e71ac882d9988cf77f32463dfeb0aaeee887fbc04b0
# Iteration 449000: nonce = 449000, hash = e74e6d3ed529d2e9d3cdba45ed84816b0f098dd25611bd30f8d45d2a1ce78e5f
# Iteration 450000: nonce = 450000, hash = 5676fff4d8ef6413bc1be812a49214e89cbf105a3eed0b3865eb35878f65ddd9
# Iteration 451000: nonce = 451000, hash = 12995f1add147372f42229fbb726486ddce4e565f206735f07bcc9f1cfe72bc2
# Iteration 452000: nonce = 452000, hash = 55f4050e82234ce1029e16f573f24811963ff410eb569a9e59c60c82b0135bf0
# Iteration 453000: nonce = 453000, hash = e4a4c80de217ff6979d51bdae4f6cfead5360b6ce3eed3e573badb460eadab91
# ...
# Iteration 215000: nonce = 215000, hash = e2f569d0c99b3c4a88ff78df82a6aa76555006d5c49344b6afcb5e12004d8e17
# Iteration 216000: nonce = 216000, hash = f510dfda192583e20bc9bb7e2a2c54e28213a3e0e4d33b26306961201d1e84a5
# Iteration 217000: nonce = 217000, hash = 9cd2f20212aef682a1a988faf802790afad0889ea0b7c0de3a84b188b26eaa5c
# Iteration 218000: nonce = 218000, hash = e2a87c866b541b2f1a7f4e931b208e5a8904290180e671d100d89df9bd9c6076
# Iteration 219000: nonce = 219000, hash = 4a2cebfa1c46bafda4232a8246f87cb1dedd9b39ae6b92c5104666374cf36ef8
# Iteration 220000: nonce = 220000, hash = ed691473fa653786082c2c83bd3d7a9f6a8bde6a794092ef02d95aeaebc1d904
# Iteration 221000: nonce = 221000, hash = 6dce72a83cb3a7c5f848b3cda3588157636fb822ab316d1750e5a8d94b327555
# Iteration 222000: nonce = 222000, hash = 672dfed2bd57e0c2f75a63652abf07eef5a740f366fa6889d175da5fa061ad08
# Iteration 223000: nonce = 223000, hash = 92fc1858683328a4a7cfecc22934536a3cc427cd641d6cd4abc82650e76dae90
# Iteration 224000: nonce = 224000, hash = c52d812bf46768957fcee078082db8a78942159af53ac5593792d38b5d22deee
# Iteration 225000: nonce = 225000, hash = be7a0e6a0469257d35c4b6a13f36ef8c35d2a28fe1aad287e236f7ca64559c9a
# Iteration 226000: nonce = 226000, hash = 921f69ceecb726ef0989f5873f362795d498a3894f1eb6c33693d8578921dd2b
# Iteration 227000: nonce = 227000, hash = 9ade46e8470f4e29ba5ee72244e06bdf93acdc6a4cb71ddee9664ed959e64afe
# Iteration 228000: nonce = 228000, hash = df41559efea62197b10c5eb4c56bf57d32701e468eea90818083225f7841f04d
# Iteration 229000: nonce = 229000, hash = 328ef74b10ea5461dd4f8951afd615a6e35bd2979baa32911e158dc51d9106c2
# Iteration 230000: nonce = 230000, hash = ca82baa9732fd4eeb50466566cac041e98929d8dc7437d9834dee4f438b3f4af
# Iteration 231000: nonce = 231000, hash = 049e917d8ce41ab7c557ffc4bdf5bb3d842adc838939fbe2b52d7f85fc6e604c
# Iteration 232000: nonce = 232000, hash = 684dfb11df8e1e6a5dcd1a2c20ddc84565fbf81f7f83fc6c9197bfd88db3e32e
# Iteration 233000: nonce = 233000, hash = 4e2f358f4a81587a0b44883c82021f55544dc45ed9a1e8a10cf8dd968563332f
# Iteration 234000: nonce = 234000, hash = b20e0815aec801838ca34d1a4981b3f0d41624c515b9af28839b19a1d2b82407
# Iteration 235000: nonce = 235000, hash = e5a3682d4dfd93e87c6ad289136ee6f3e85dbde472998761e74a28278e371e57
# Iteration 236000: nonce = 236000, hash = 9b989a18ac2099980113b127615bc3e6130d1ab1c08e7d83f53b28387108ecff
# Iteration 237000: nonce = 237000, hash = 1cc78ebb59a8b1f7d819380730d0883d56f0d068999061ff5b19f9ed3fc30556
# Iteration 238000: nonce = 238000, hash = ada80a226309f74db4797e64d91fa7e1e900abfda1889084dcdcd0592ba8d93d
# Iteration 239000: nonce = 239000, hash = 6e0ef480a03d2d11f742d07b918999ca30bce7fef2917cf0d75e57acc9a0cee6
# Iteration 240000: nonce = 240000, hash = 8021b2e091b51bcdf5dce9b3b38591792b35241e516c7883e19fbe3f164850d8
# Iteration 241000: nonce = 241000, hash = 0beff24c35284687bde9297f42cd898f36f9c3fb7121d4479efadef5c1b4c4c5
# Iteration 242000: nonce = 242000, hash = 0a56bf551412c8609355b8f006a7ff0713ba8f1c196f9f1a4d33d68ef8f45b80
# Iteration 243000: nonce = 243000, hash = f76a88eb1a1d327fb7a17dd820b6252a501837012d38cd0fd36018a0d9c9886f
# Iteration 244000: nonce = 244000, hash = 038437d3b975fb9a9fac4f5d24f3c0a161b155059ef46617ad6c1a72feca4dd5
# Iteration 245000: nonce = 245000, hash = 81f39d3822c3b08785f48803418d0d24044c9973bed5c6e92800c277b4b917e2
# Iteration 246000: nonce = 246000, hash = ff565d0b096b487ab2121de58ac47a7d67ffcfe932226f4bce00948fe65c89ab
# Iteration 247000: nonce = 247000, hash = 1cde3110822db8b7311373594ebf35056715312839beaa2f2fb447ee1d444bec
# Iteration 248000: nonce = 248000, hash = 0f76c40be15bf2693d4e2ec90bca250f590dee2e85d00770bc5b4b814485b967
# Iteration 249000: nonce = 249000, hash = d210f4b3bb3a65d25d477c9c205bdd887acf6a486395571eced15b4fba75e4e6
# Iteration 250000: nonce = 250000, hash = cc8fdb9af290a80f8e11c223f1b84fffb75fb8001fc71bba1c04c1a6864b29f2
# Iteration 251000: nonce = 251000, hash = f7633742ce1f1f2c16bb2b8edbdfb6217b3c67f094243b4acc5b78239b030a48
# Iteration 252000: nonce = 252000, hash = 26260d5190113b1111508683da68a1aea0520deba93f14b43ff8bdbc67f8e6ed
# Iteration 253000: nonce = 253000, hash = 77a85bfef921bc7d4820b528864ecb51532f69e19f61b375876052732936af33
# Iteration 254000: nonce = 254000, hash = e19f124a6b994948d261fd8e43b403e6df6e8d153e98a334c5bf2e94758e7b3c
# Iteration 255000: nonce = 255000, hash = c3df59650f5b42261d7619163dacf4a79a8460fae2065d3b216d11b9f9d69f23
# Iteration 256000: nonce = 256000, hash = 6b87c74b5c12004edaadcfe51af2b4833a0d2788146187555e230550cdc4fa75
# Iteration 257000: nonce = 257000, hash = e30c717122669cfcef2ed406836d851ce54b0231db2132fa54b0991cf0a21559
# Iteration 258000: nonce = 258000, hash = e288f6775b5e2225315b324ae4292b5419b5acc71a3f108c6509a0a9d61726b1
# Iteration 259000: nonce = 259000, hash = 7aeee6fec472887b90078aa1fcaffc90559bbfef8f2a550d8298e61965292472
# Iteration 260000: nonce = 260000, hash = 21bcff4b8c72cb21bc39f5e194ad55af5db38f20ec752adde4beabbe6858128a
# Iteration 261000: nonce = 261000, hash = a6482ce4122844e2932889e14eed810207d366c89b4a5070ac88d33603a7fcd4
# Iteration 262000: nonce = 262000, hash = 9faa7b97bf40eae45919dd0b818737d1297301dd5ed4b7117589eae65e59bfa4
# Iteration 263000: nonce = 263000, hash = 2dd1203391c985a01c70d8a05557e71d57d2cd6e2d53f3804c351089b02f3365
# Iteration 264000: nonce = 264000, hash = efad2a46f560890200ddd7af2c8836ec1fdfc96d42b28d9245d024410a6080b3
# Iteration 265000: nonce = 265000, hash = b38dac4d9cc83248004ba4c7d02bb4ef7c5d9404bbe6dd3f2363df6b7ea12c7f
# Iteration 266000: nonce = 266000, hash = 79cdb863852c02ffb4e21b96978c0af937015357d932a3529ec333b584957ead
# Iteration 267000: nonce = 267000, hash = c4bd34134664cffff62dc1ce2b7b093293f8a10d4ef243c98888145478f3d97c
# Iteration 268000: nonce = 268000, hash = 9de3a46792f7190d98a29cbcdab5cd1538181c2feea93b4baf1e46eb2f904e85
# Iteration 269000: nonce = 269000, hash = 58b72a549a85c4c48f73237be2735f9efa7f28d63b7a4b0d27a61d663b19d343
# Iteration 270000: nonce = 270000, hash = 56bd20ccbe5d01ee07e664d30088d49d0b7b3a6e3000e4e33e34cd753caf542c
# Iteration 271000: nonce = 271000, hash = c72071af811e6650bae7174386d273aaa57c8f4abadc7c84ecad757eb3b15bda
# Iteration 272000: nonce = 272000, hash = aa6ca5449823b10918bf78a88d955f206ef4dfdf6f94206c613901be7f142cac
# Iteration 273000: nonce = 273000, hash = e7cf747cd2a24397c51118b55b2efa357c6e85a85d30dbd34cd69d9f28caf2d3
# Iteration 274000: nonce = 274000, hash = 31d83e8ecfd5840cecd8faf09e9139d3a2725c429f28d38b006857f4aecba32f
# Iteration 275000: nonce = 275000, hash = 9505c6b10d2291b6936203f412dfe23618d981620ea235b548b99f0f0e754e18
# Iteration 276000: nonce = 276000, hash = c4e6206db6420cb3bf09481d8919df7baaa1b277177fa946844e2ad2046b933b
# Iteration 277000: nonce = 277000, hash = a113518509b649cb1314f6f159f27cb65db6b256cb80ad10615e6d14c944b17c
# Iteration 278000: nonce = 278000, hash = 7427965114319de8dac6ec8c7c77fda5d4c42fe6ba55677abffa97a1b8796824
# Iteration 279000: nonce = 279000, hash = aaec1f5d03046c9b68b0048228b0195b206720ed7917b2193d282733a689813f
# Iteration 280000: nonce = 280000, hash = dcd0d1969986b8a59f18e1aabe6fcb978875fafef021b571357b91fb89562cc5
# Iteration 281000: nonce = 281000, hash = df62d0d9fb5fd162ff101e7633e1059ef3e45afaec1abc816c014319f4c75cc5
# Iteration 282000: nonce = 282000, hash = d163e9f87bad3b3ba873a7d92513c3a62b0da23343427c2e2e57f2a58610f104
# Iteration 283000: nonce = 283000, hash = 6ae4c9f7df5da014b7093feccd71d4704b228b9a8e317dd8fd7ca8c67ac7056e
# Iteration 284000: nonce = 284000, hash = b7f1cfd2f12bd5dddef6310622469d68d1f5ae539e2595575d1ff1aebfb5231a
# Iteration 285000: nonce = 285000, hash = dd23a5578e8cde4714805da24b8356dcdeb4a0099b9e8be8822677ca5b59fe9b
# Iteration 286000: nonce = 286000, hash = 91063522eea04df33a8672ebaeb0575229e46ab1778d31d077db753037a43f54
# Iteration 287000: nonce = 287000, hash = 0c282bdc528d62f5e076184cca151f91768e68a22caf415eb9df570b495134dc
# Iteration 288000: nonce = 288000, hash = 544d5ff4f5d0e9b6e29eb1695b9dbdceb369170cd6251368bd0fadc2c57fe457
# Iteration 289000: nonce = 289000, hash = 760f196fd9cbf5f0e17c7a8dccdd3ddaf57f955268b89966f880e418b563e8ac
# Iteration 290000: nonce = 290000, hash = 81fd39ba37084a89e02a4808d9c95ef054b09d8586ebb45355e5f994ba1eec25
# Iteration 291000: nonce = 291000, hash = 9dfb537ce80c4494b19278f467549cd53776933a470d04e2141ea0d9efbfc173
# Iteration 292000: nonce = 292000, hash = fc83c7395dc1ab4e3128de8e8118ca945752e2d4ab04e18d8b7b0860f04fa913
# Iteration 293000: nonce = 293000, hash = 4772afc0d4277d115139c9e1c95738456b096e7347e65729188203d8dec3ae68
# Iteration 294000: nonce = 294000, hash = bd36166fb82240e67558786cdeaa93042b1b5d3be045d1778cb71ac647a63093
# Iteration 295000: nonce = 295000, hash = 8c3330b86b03a701e198e0762b578a794f425bde5b6943fee720751d211bcea7
# Iteration 296000: nonce = 296000, hash = 39666a16bf4b49a08b89b4ac7b6b40c15070c74ad7a19f3a19acf3da45447578
# Iteration 297000: nonce = 297000, hash = 57957eb15b154b845012f85e7a7dcdbfc9acd4168f9001b477e206ea8c7dc6aa
# Iteration 298000: nonce = 298000, hash = dc75cb2db20effb5237c003509cd81cd044b5fe11708384ff4592bb99c66bcd7
# Iteration 299000: nonce = 299000, hash = 8136d6fe96fb3013b44eeb3108c6da9020b78262465ff9085d0531c262857a39
# Iteration 300000: nonce = 300000, hash = e5a998423f94895e3754876189022150466250627318adfaa3add6974eb38c89
# Iteration 301000: nonce = 301000, hash = 41f69cae05455c28581c1c2a2ee6f847ee9de5332df82797804daa74848f2877
# Iteration 302000: nonce = 302000, hash = 71c3bd09d517ef12f19133706bf3845370b5757eac033233f7b996a93b0bf9db
# Iteration 303000: nonce = 303000, hash = 8339900498aa32afaef23a7541cde994096e4d3398900317234002433c0a390a
# Iteration 304000: nonce = 304000, hash = 42f96000a22e535076566ee8e5a30bf9ab4227fd3e97107f05b6ff9c778ecf27
# Iteration 305000: nonce = 305000, hash = 878e60e531da405a62bd15dd71f48f8b927a6579c4c05f5dba523a2bc5b579c7
# Iteration 306000: nonce = 306000, hash = 13f05f1cab05136174e2e458f1c25b757fc53d0e1f4b483d5f82d2979a6c410b
# Iteration 307000: nonce = 307000, hash = 1ffd61d8d88cf955c0e578371db7fbf45d2feb24dbbaefdbc65777b75b4949d3
# Iteration 308000: nonce = 308000, hash = 2ebf960ec5dc52a0cd2ef1204ea8593a24d2918a5863df1dd84fb194d6bbc3a5
# Block 2 mined after 308670 iterations!
# Final nonce: 308670, Final hash: 00000f49c6700feb18fe97a3d7ce37494cb1b2d1b0f1e0b5f42e360fa462cba1
#
# Added Block 2:
# Index: 2
# Timestamp: 1742829914.7940602
# Data: Transaction C to D: $20
# Previous Hash: 000001b4f22f0f038bda203ecd2bd8008c93083e5a6107ba0162e7a6544b5a4f
# Nonce: 308670
# Hash: 00000f49c6700feb18fe97a3d7ce37494cb1b2d1b0f1e0b5f42e360fa462cba1
# --------------------------------------------------
#
# Starting mining for Block 3 with target: 0xffff0000000000000000000000000000000000000000000000000000000
# Iteration 1000: nonce = 1000, hash = d5f3b03858c0b9375bf23e0d1ed01cc7a4e768f5bc7adfa9360767336fd9e94a
# Iteration 2000: nonce = 2000, hash = f71b78d91f34924eaa4fd95fdb313359ce61fcecf6a5e1722d1a84431f5cb619
# Iteration 3000: nonce = 3000, hash = 7a0f7c57e97c6f8297f4acab36241c35ad6db37ad0f59a3091d44e15109518cc
# Iteration 4000: nonce = 4000, hash = 1b39d806dc0e3687894d6790cd9d91489f8ab490557f4918e3eac14ce5b81927
# Iteration 5000: nonce = 5000, hash = 5fca9e190de095e6faf9f380272089de443e9c2c789d85135c15b17e59ca9c73
# Iteration 6000: nonce = 6000, hash = c3d4bc31707e03431bf40694904b6bfa5b805e68e5c5a882fbf16053ad860a04
# Iteration 7000: nonce = 7000, hash = d533459b7fab012de4010a6da712073f15e2edd32b905160088b9f7c0acb17d8
# Iteration 8000: nonce = 8000, hash = bced23342e5443459f87f84d36ceebcf727c9af01679582697fa99b58b46e9ce
# Iteration 9000: nonce = 9000, hash = 931469345b3abb44abfff11e739564139383d6edb79ae36c2cb3f98454e1f247
# Iteration 10000: nonce = 10000, hash = d8cf6308b96caf17667fe9e4198125fd76f60f50260ac0b5174f5af163429401
# Iteration 11000: nonce = 11000, hash = b7f905650e13831d47dd704d882a4c6a21ffe4f2463e11bc61187ba6048b72b0
# Iteration 12000: nonce = 12000, hash = c1f5ffffbfd60aadc0eaac88e82abb9fc457af60090826380b7a9bc7aac4a890
# Iteration 13000: nonce = 13000, hash = 4906f90948db9a082b1e8c0df434ff9a953801b983d20434207590f4e9668c24
# Iteration 14000: nonce = 14000, hash = 986000a66f61de8458863ef6e41a9a1ed1ffa63cf2e4387f3667d9937b14b82c
# Iteration 15000: nonce = 15000, hash = e5b1fe6a913e78b9c7be92862b31632b29aa140048064fe2bee9df96e49be896
# Iteration 16000: nonce = 16000, hash = 2e31e9fecb3d441c6fcd87b9771b007a5f0663b61ff14c56a8fa3ee6fd801388
# Iteration 17000: nonce = 17000, hash = 77f6be10547ef11a36f8e93f233cda2e6f24157cb8151de08eeb316b182c9413
# Iteration 18000: nonce = 18000, hash = b343e1a2ff16ef752bf895b7c022605bb60fa9bd23c2528782251d90d6f62162
# Iteration 19000: nonce = 19000, hash = 01eee50d599550df69a228c625d5196d3373e53e5777a1824a8299132d9866e1
# Iteration 20000: nonce = 20000, hash = 19e3269bf7c546533f8420132396b831dd3787ae886de56474bc2a85b85f8156
# Iteration 21000: nonce = 21000, hash = ad46d842b15c41f88f52017de33c175114a976903d8b9682f92fc922fbb2a307
# Iteration 22000: nonce = 22000, hash = 7304c30bf5a654f684525e88eab6a420e04e7521d032d25a77322daa488776ec
# Iteration 23000: nonce = 23000, hash = 7d133c9eeec0de37801cc90074c2acd485506589dac63a4957319e94ec3e4be0
# Iteration 24000: nonce = 24000, hash = 1ec67636858136223e5b9f1c22540db43e30854c74370d1381f4c3a9875ee774
# Iteration 25000: nonce = 25000, hash = 2152f0a635aa99de888a1eeafe6a8a2397f6c6e98eb4220c796330d1566707c9
# Iteration 26000: nonce = 26000, hash = f39dca45a4b777ae3450dd1cdfe3e40152989f4821b3cca4d4e013d94d286beb
# Iteration 27000: nonce = 27000, hash = 5d5cefe0acfdad463ebbf68bddbc16549052056dd502dc37b5c796d36f307b83
# Iteration 28000: nonce = 28000, hash = 431d2b0532af671797e6f85df726228c719521def1a76b8159e3c5aa2d4f1ac9
# Iteration 29000: nonce = 29000, hash = 4b70c7699c73e1b42d1c0ee68280be5bc3c01d6b5b49eb9dd40ccdf7d878c8ef
# Iteration 30000: nonce = 30000, hash = 0f933bbc6d3175211af9aa9809c80cb5b8068e2d58ad53793bd06e440ca3d2d3
# Iteration 31000: nonce = 31000, hash = a00b2d913ca6960c1901ba82dd541aa60d98122769762693c22af78a3cd1ab7d
# Iteration 32000: nonce = 32000, hash = 39cce7465516226aafeec9965717ff33ada4152d28a19a005d8215512521714e
# Iteration 33000: nonce = 33000, hash = 35ffc28624821006ba1d422a2f51e98ef3a1e67e7d1b9556dbb5ffde30653e79
# Iteration 34000: nonce = 34000, hash = 9f0884d778caa587064c22f3ad6922698164929d825f9a75a33da8fa1498966f
# Iteration 35000: nonce = 35000, hash = f4c71f3443c5c61ba1889b666ee5bce9adc318997d4586b278eae7c99180a947
# Iteration 36000: nonce = 36000, hash = 751328e47f0695d412aa1aa1edae4aa7b7970d098e94712aade927d58a5bbd77
# Iteration 37000: nonce = 37000, hash = 82a219271e858f726d1832818302cc84ccac11f13f2815c4cdd0e61fdcba99a3
# Iteration 38000: nonce = 38000, hash = 79b39887253256d9cc6c3b60772511f4e41c191073413c3ab952ddb517f0cc2b
# Iteration 39000: nonce = 39000, hash = 336034acdf6839b41496aabdbbfca60e58ade77a458385342bdf5c997b2d60ae
# Iteration 40000: nonce = 40000, hash = f67fc42c50c7a723382eba5156a577864c709d18b4842821ce0451134c9c156d
# Iteration 41000: nonce = 41000, hash = 599e1e06f623f01ff1c7b1b319a2d835a1a3cd97664d38f476ac65230c6ccb37
# Iteration 42000: nonce = 42000, hash = e7fe6ebb91e09c48bfcb928fad274759aacc95d84c71eb80300767deb6140484
# Iteration 43000: nonce = 43000, hash = 217d50ddaedbe5ef74f959f216f2c4bf7a8f8b56d752ff440ea9df8e26932446
# Iteration 44000: nonce = 44000, hash = 0a31c2e7aa91b6d9001f7e68ca6ee33aca9d6aed8ebbf0154f3b1fbf867f5e78
# Iteration 45000: nonce = 45000, hash = 82be3009a61b19f83ee0be41d37c5c8b9b9dc928a8898b3d82870fe796b9ea43
# Iteration 46000: nonce = 46000, hash = 1a15f8125197d90fef185f8919ac54368bdfcb70f1745c8d53b710f089bd189f
# Iteration 47000: nonce = 47000, hash = a1ac3c959a81064220716189e8819f34dcee3e90c3b81aac494a77895fe9e557
# Iteration 48000: nonce = 48000, hash = 5f290c40aedda07ad7278eb341ed2b4f86cb032cfd914e6f6200f24985ca9755
# Block 3 mined after 48708 iterations!
# Final nonce: 48708, Final hash: 00000a208df898ff17294387b86881a1e518c534aea7a381f603f4c4f72d59bf
#
# Added Block 3:
# Index: 3
# Timestamp: 1742829915.5949755
# Data: Transaction E to F: $100
# Previous Hash: 00000f49c6700feb18fe97a3d7ce37494cb1b2d1b0f1e0b5f42e360fa462cba1
# Nonce: 48708
# Hash: 00000a208df898ff17294387b86881a1e518c534aea7a381f603f4c4f72d59bf
# --------------------------------------------------

# %%
# Print detailed information for every block in the blockchain.
print("Complete Blockchain Details:")
blockchain.display_chain()
# Out:
# Complete Blockchain Details:
# Index: 0
# Timestamp: 1742829912.5727808
# Data: Genesis Block
# Previous Hash: 0
# Nonce: 245022
# Hash: 000007b53e47c6f6fea7e8c1b1cc932a9d58f827cfbb1fcc2753aaedbf15118d
# --------------------------------------------------
# Index: 1
# Timestamp: 1742829913.111326
# Data: Transaction A to B: $50
# Previous Hash: 000007b53e47c6f6fea7e8c1b1cc932a9d58f827cfbb1fcc2753aaedbf15118d
# Nonce: 777041
# Hash: 000001b4f22f0f038bda203ecd2bd8008c93083e5a6107ba0162e7a6544b5a4f
# --------------------------------------------------
# Index: 2
# Timestamp: 1742829914.7940602
# Data: Transaction C to D: $20
# Previous Hash: 000001b4f22f0f038bda203ecd2bd8008c93083e5a6107ba0162e7a6544b5a4f
# Nonce: 308670
# Hash: 00000f49c6700feb18fe97a3d7ce37494cb1b2d1b0f1e0b5f42e360fa462cba1
# --------------------------------------------------
# Index: 3
# Timestamp: 1742829915.5949755
# Data: Transaction E to F: $100
# Previous Hash: 00000f49c6700feb18fe97a3d7ce37494cb1b2d1b0f1e0b5f42e360fa462cba1
# Nonce: 48708
# Hash: 00000a208df898ff17294387b86881a1e518c534aea7a381f603f4c4f72d59bf
# --------------------------------------------------

# %%
# Finally, display the hash of every block in the blockchain.
print("Hashes of all blocks in the blockchain:")
for block in blockchain.chain:
    print(f"Block {block.index} hash: {block.hash}")
# Out:
# Hashes of all blocks in the blockchain:
# Block 0 hash: 000007b53e47c6f6fea7e8c1b1cc932a9d58f827cfbb1fcc2753aaedbf15118d
# Block 1 hash: 000001b4f22f0f038bda203ecd2bd8008c93083e5a6107ba0162e7a6544b5a4f
# Block 2 hash: 00000f49c6700feb18fe97a3d7ce37494cb1b2d1b0f1e0b5f42e360fa462cba1
# Block 3 hash: 00000a208df898ff17294387b86881a1e518c534aea7a381f603f4c4f72d59bf

# %%
print("Starting step-by-step blockchain verification...\n")

# Iterate through the blockchain starting from the second block.
for i in range(1, len(blockchain.chain)):
    current = blockchain.chain[i]
    previous = blockchain.chain[i - 1]
    
    print(f"Verifying Block {current.index}:")
    
    # Recompute the current block's hash.
    recomputed_hash = current.compute_hash()
    print(f"  Stored hash:    {current.hash}")
    print(f"  Recomputed hash:{recomputed_hash}")
    
    if current.hash == recomputed_hash:
        print("  [OK] Block hash is valid.")
    else:
        print("  [ERROR] Block hash mismatch!")
    
    # Check that the current block correctly references the previous block's hash.
    print(f"  Previous hash in block: {current.previous_hash}")
    print(f"  Hash of previous block: {previous.hash}")
    
    if current.previous_hash == previous.hash:
        print("  [OK] Previous hash is valid.")
    else:
        print("  [ERROR] Previous hash mismatch!")
    
    print("-" * 50)

print("Blockchain verification complete!")
# Out:
# Starting step-by-step blockchain verification...
#
# Verifying Block 1:
#   Stored hash:    000001b4f22f0f038bda203ecd2bd8008c93083e5a6107ba0162e7a6544b5a4f
#   Recomputed hash:000001b4f22f0f038bda203ecd2bd8008c93083e5a6107ba0162e7a6544b5a4f
#   [OK] Block hash is valid.
#   Previous hash in block: 000007b53e47c6f6fea7e8c1b1cc932a9d58f827cfbb1fcc2753aaedbf15118d
#   Hash of previous block: 000007b53e47c6f6fea7e8c1b1cc932a9d58f827cfbb1fcc2753aaedbf15118d
#   [OK] Previous hash is valid.
# --------------------------------------------------
# Verifying Block 2:
#   Stored hash:    00000f49c6700feb18fe97a3d7ce37494cb1b2d1b0f1e0b5f42e360fa462cba1
#   Recomputed hash:00000f49c6700feb18fe97a3d7ce37494cb1b2d1b0f1e0b5f42e360fa462cba1
#   [OK] Block hash is valid.
#   Previous hash in block: 000001b4f22f0f038bda203ecd2bd8008c93083e5a6107ba0162e7a6544b5a4f
#   Hash of previous block: 000001b4f22f0f038bda203ecd2bd8008c93083e5a6107ba0162e7a6544b5a4f
#   [OK] Previous hash is valid.
# --------------------------------------------------
# Verifying Block 3:
#   Stored hash:    00000a208df898ff17294387b86881a1e518c534aea7a381f603f4c4f72d59bf
#   Recomputed hash:00000a208df898ff17294387b86881a1e518c534aea7a381f603f4c4f72d59bf
#   [OK] Block hash is valid.
#   Previous hash in block: 00000f49c6700feb18fe97a3d7ce37494cb1b2d1b0f1e0b5f42e360fa462cba1
#   Hash of previous block: 00000f49c6700feb18fe97a3d7ce37494cb1b2d1b0f1e0b5f42e360fa462cba1
#   [OK] Previous hash is valid.
# --------------------------------------------------
# Blockchain verification complete!
