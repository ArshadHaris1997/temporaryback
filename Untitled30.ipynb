# %%
import pandas as pd

# %%
df=pd.read_csv("bowler_performance.csv")

# %%
df
# Out:
#                bowler  death_over_economy  death_over_strike_rate  \
# 0      Jasprit Bumrah                 7.6                      13
# 1      Mitchell Starc                 9.3                      12
# 2         Pat Cummins                 8.3                      16
# 3   Bhuvneshwar Kumar                 8.7                      12
# 4         Trent Boult                 8.2                      10
# 5      Lasith Malinga                 9.2                      20
# 6        Chris Jordan                 7.6                      13
# 7       Kagiso Rabada                 8.1                      11
# 8          Shaun Tait                 7.5                      12
# 9          Dale Steyn                 9.3                      11
# 10         Andrew Tye                 7.2                      14
# 11       Jofra Archer                 9.0                      19
#
#     yorker_accuracy  slower_ball_effectiveness  pressure_performance  \
# ...
